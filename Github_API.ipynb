# %%
# !pip install PyGithub requests
# !pip install gitpython
# Out:
# ^C

# %%
import requests
import base64
from github import Github
from pprint import pprint
import datetime, time# for sleep

# github username
username = "stockpy"
password = "Dlfdltka123!"
# url to request
url = f"https://api.github.com/users/{username}"
# make the request and return the json
user_data = requests.get(url).json()
# pretty print JSON data
pprint(user_data)
print("############### 1")
time.sleep(1)
# pygithub object
g = Github()
# get that user by username
user = g.get_user(username)

for repo in user.get_repos():
    print(repo)
print("############### 2")
time.sleep(1)
def print_repo(repo):
    # repository full name
    print("Full name:", repo.full_name)
    # repository description
    print("Description:", repo.description)
    # the date of when the repo was created
    print("Date created:", repo.created_at)
    # the date of the last git push
    print("Date of last push:", repo.pushed_at)
    # home website (if available)
    print("Home Page:", repo.homepage)
    # programming language
    print("Language:", repo.language)
    # number of forks
    print("Number of forks:", repo.forks)
    # number of stars
    print("Number of stars:", repo.stargazers_count)
    print("-"*50)
    # repository content (files & directories)
    print("Contents:")
    for content in repo.get_contents(""):
        print(content)
    try:
        # repo license
        print("License:", base64.b64decode(repo.get_license().content.encode()).decode())
    except:
        pass
print("############### 3")
time.sleep(1)
print_repo(repo)
print("############### 4")
time.sleep(1)
# iterate over all public repositories
for repo in user.get_repos():
    print_repo(repo)
    print("="*100)
print("############### 5")
time.sleep(1)
# authenticate to github
# g = Github(username, password)
# get the authenticated user
# user = g.get_user()
for repo in user.get_repos():
    print_repo(repo)

print("############### 6")
time.sleep(1)
# create a file and commit n push
repo.create_file("Stock_202011125.html", "commit message", "Stock_202011125.html-- TEST")
print("############### 7")
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/64298149?v=4',
#  'bio': None,
#  'blog': '',
#  'company': None,
#  'created_at': '2020-04-25T04:39:49Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/stockpy/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/stockpy/followers',
#  'following': 0,
#  'following_url': 'https://api.github.com/users/stockpy/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/stockpy/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/stockpy',
#  'id': 64298149,
#  'location': None,
#  'login': 'stockpy',
#  'name': None,
#  'node_id': 'MDQ6VXNlcjY0Mjk4MTQ5',
#  'organizations_url': 'https://api.github.com/users/stockpy/orgs',
#  'public_gists': 1,
#  'public_repos': 1,
#  'received_events_url': 'https://api.github.com/users/stockpy/received_events',
#  'repos_url': 'https://api.github.com/users/stockpy/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/stockpy/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/stockpy/subscriptions',
#  'twitter_username': None,
#  'type': 'User',
#  'updated_at': '2021-02-25T12:43:25Z',
#  'url': 'https://api.github.com/users/stockpy'}
# ############### 1
# Repository(full_name="stockpy/stockpy.github.io")
# ############### 2
# ############### 3
# Full name: stockpy/stockpy.github.io
# Description: None
# Date created: 2020-05-05 02:13:08
# Date of last push: 2020-12-24 05:54:52
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# Contents:
# ContentFile(path="20200831.html")
# ContentFile(path="ADMINISTRATION.html")
# ContentFile(path="APPLICATION.html")
# ContentFile(path="BACKUP.html")
# ContentFile(path="BBA.html")
# ContentFile(path="BB_ADMINISTRATION.html")
# ContentFile(path="BB_APPLICATION.html")
# ContentFile(path="BB_BACKUP.html")
# ContentFile(path="BB_ColTotal.html")
# ContentFile(path="BB_DISKS.html")
# ContentFile(path="BB_LICENSE.html")
# ContentFile(path="BB_LOCKS.html")
# ContentFile(path="BB_MEMORY.html")
# ContentFile(path="BB_Main.html")
# ContentFile(path="BB_MiniCheck_Inform.html")
# ContentFile(path="BB_OBJECTS.html")
# ContentFile(path="BB_OPERATION SYSTEM.html")
# ContentFile(path="BB_OPERATION_SYSTEM.html")
# ContentFile(path="BB_OPRATION_SYSTEM.html")
# ContentFile(path="BB_One.html")
# ContentFile(path="BB_SQL.html")
# ContentFile(path="BB_STATISTICS.html")
# ContentFile(path="BB_TABLES.html")
# ContentFile(path="BB_전 체.html")
# ContentFile(path="DISKS.html")
# ContentFile(path="D_\Python\Log\Profit_20201223.html")
# ContentFile(path="Echart_ADMINISTRATION.html")
# ContentFile(path="Echart_APPLICATION.html")
# ContentFile(path="Echart_BACKUP.html")
# ContentFile(path="Echart_DISKS.html")
# ContentFile(path="Echart_LICENSE.html")
# ContentFile(path="Echart_LOCKS.html")
# ContentFile(path="Echart_MEMORY.html")
# ContentFile(path="Echart_OBJECTS.html")
# ContentFile(path="Echart_OPERATION SYSTEM.html")
# ContentFile(path="Echart_SQL.html")
# ContentFile(path="Echart_STATISTICS.html")
# ContentFile(path="Echart_TABLES.html")
# ContentFile(path="Echart_Test.html")
# ContentFile(path="Echart_Test_1.html")
# ContentFile(path="Hot_Spot.html")
# ContentFile(path="LICENSE.html")
# ContentFile(path="LOCKS.html")
# ContentFile(path="MEMORY.html")
# ContentFile(path="MiniCheck.py")
# ContentFile(path="MiniCheck_BB.py")
# ContentFile(path="MiniCheck_Inform.html")
# ContentFile(path="OBJECTS.html")
# ContentFile(path="OPRATION_SYSTEM.html")
# ContentFile(path="Porfit_20200925.html")
# ContentFile(path="Porfit_20200928.html")
# ContentFile(path="Porfit_20200929.html")
# ContentFile(path="Profit_20200905.html")
# ContentFile(path="Profit_20200906.html")
# ContentFile(path="Profit_20201006.html")
# ContentFile(path="Profit_20201007.html")
# ContentFile(path="Profit_20201008.html")
# ContentFile(path="Profit_20201012.html")
# ContentFile(path="Profit_20201013.html")
# ContentFile(path="Profit_20201015.html")
# ContentFile(path="Profit_20201016.html")
# ContentFile(path="Profit_20201020.html")
# ContentFile(path="Profit_20201021.html")
# ContentFile(path="Profit_20201022.html")
# ContentFile(path="Profit_20201023.html")
# ContentFile(path="Profit_20201027.html")
# ContentFile(path="Profit_20201028.html")
# ContentFile(path="Profit_20201029.html")
# ContentFile(path="Profit_20201030.html")
# ContentFile(path="Profit_20201102.html")
# ContentFile(path="Profit_20201103.html")
# ContentFile(path="Profit_20201104.html")
# ContentFile(path="Profit_20201105.html")
# ContentFile(path="Profit_20201109.html")
# ContentFile(path="Profit_20201111.html")
# ContentFile(path="Profit_20201112.html")
# ContentFile(path="Profit_20201113.html")
# ContentFile(path="Profit_20201223.html")
# ContentFile(path="README.md")
# ContentFile(path="SQL.html")
# ContentFile(path="STATISTICS.html")
# ContentFile(path="TABLES.html")
# ContentFile(path="TEST_Echart_1.html")
# ContentFile(path="Word_Cloud_Line.py")
# ContentFile(path="_config.yml")
# ContentFile(path="billboard.html")
# ContentFile(path="billboard.min.css")
# ContentFile(path="billboard.pkgd.min.js")
# ContentFile(path="echarts.js")
# ContentFile(path="echarts.min.js")
# ContentFile(path="index.html")
# ContentFile(path="minicheck_result.txt")
# ContentFile(path="minicheck_tes.txt")
# ContentFile(path="minicheck_test.txt")
# ContentFile(path="minicheck_test_1.txt")
# ContentFile(path="minicheck_test_2.txt")
# ContentFile(path="render.html")
# ContentFile(path="test.html")
# ContentFile(path="test.txt")
# ContentFile(path="test_another.html")
# ContentFile(path="venv")
# License:
#     <html>
#       <meta charset="utf-8">
#       <head><title>HTML Pandas Dataframe with CSS</title></head>
#       <link rel="stylesheet" type="text/css" href="billboard.min.css"/>
#       <body>
#         <table border="1" class="dataframe mystyle">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>Category</th>
#       <th>DESCRIPTION</th>
#       <th>VALUE</th>
#       <th>CHECK</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>336</th>
#       <td>LICENSE</td>
#       <td>License usage (%)</td>
#       <td>171</td>
#       <td>NOT OK</td>
#     </tr>
#   </tbody>
# </table>
#       </body>
#     </html>
#
# ############### 4
# Full name: stockpy/stockpy.github.io
# Description: None
# Date created: 2020-05-05 02:13:08
# Date of last push: 2020-12-24 05:54:52
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# Contents:
# ContentFile(path="20200831.html")
# ContentFile(path="ADMINISTRATION.html")
# ContentFile(path="APPLICATION.html")
# ContentFile(path="BACKUP.html")
# ContentFile(path="BBA.html")
# ContentFile(path="BB_ADMINISTRATION.html")
# ContentFile(path="BB_APPLICATION.html")
# ContentFile(path="BB_BACKUP.html")
# ContentFile(path="BB_ColTotal.html")
# ContentFile(path="BB_DISKS.html")
# ContentFile(path="BB_LICENSE.html")
# ContentFile(path="BB_LOCKS.html")
# ContentFile(path="BB_MEMORY.html")
# ContentFile(path="BB_Main.html")
# ContentFile(path="BB_MiniCheck_Inform.html")
# ContentFile(path="BB_OBJECTS.html")
# ContentFile(path="BB_OPERATION SYSTEM.html")
# ContentFile(path="BB_OPERATION_SYSTEM.html")
# ContentFile(path="BB_OPRATION_SYSTEM.html")
# ContentFile(path="BB_One.html")
# ContentFile(path="BB_SQL.html")
# ContentFile(path="BB_STATISTICS.html")
# ContentFile(path="BB_TABLES.html")
# ContentFile(path="BB_전 체.html")
# ContentFile(path="DISKS.html")
# ContentFile(path="D_\Python\Log\Profit_20201223.html")
# ContentFile(path="Echart_ADMINISTRATION.html")
# ContentFile(path="Echart_APPLICATION.html")
# ContentFile(path="Echart_BACKUP.html")
# ContentFile(path="Echart_DISKS.html")
# ContentFile(path="Echart_LICENSE.html")
# ContentFile(path="Echart_LOCKS.html")
# ContentFile(path="Echart_MEMORY.html")
# ContentFile(path="Echart_OBJECTS.html")
# ContentFile(path="Echart_OPERATION SYSTEM.html")
# ContentFile(path="Echart_SQL.html")
# ContentFile(path="Echart_STATISTICS.html")
# ContentFile(path="Echart_TABLES.html")
# ContentFile(path="Echart_Test.html")
# ContentFile(path="Echart_Test_1.html")
# ContentFile(path="Hot_Spot.html")
# ContentFile(path="LICENSE.html")
# ContentFile(path="LOCKS.html")
# ContentFile(path="MEMORY.html")
# ContentFile(path="MiniCheck.py")
# ContentFile(path="MiniCheck_BB.py")
# ContentFile(path="MiniCheck_Inform.html")
# ContentFile(path="OBJECTS.html")
# ContentFile(path="OPRATION_SYSTEM.html")
# ContentFile(path="Porfit_20200925.html")
# ContentFile(path="Porfit_20200928.html")
# ContentFile(path="Porfit_20200929.html")
# ContentFile(path="Profit_20200905.html")
# ContentFile(path="Profit_20200906.html")
# ContentFile(path="Profit_20201006.html")
# ContentFile(path="Profit_20201007.html")
# ContentFile(path="Profit_20201008.html")
# ContentFile(path="Profit_20201012.html")
# ContentFile(path="Profit_20201013.html")
# ContentFile(path="Profit_20201015.html")
# ContentFile(path="Profit_20201016.html")
# ContentFile(path="Profit_20201020.html")
# ContentFile(path="Profit_20201021.html")
# ContentFile(path="Profit_20201022.html")
# ContentFile(path="Profit_20201023.html")
# ContentFile(path="Profit_20201027.html")
# ContentFile(path="Profit_20201028.html")
# ContentFile(path="Profit_20201029.html")
# ContentFile(path="Profit_20201030.html")
# ContentFile(path="Profit_20201102.html")
# ContentFile(path="Profit_20201103.html")
# ContentFile(path="Profit_20201104.html")
# ContentFile(path="Profit_20201105.html")
# ContentFile(path="Profit_20201109.html")
# ContentFile(path="Profit_20201111.html")
# ContentFile(path="Profit_20201112.html")
# ContentFile(path="Profit_20201113.html")
# ContentFile(path="Profit_20201223.html")
# ContentFile(path="README.md")
# ContentFile(path="SQL.html")
# ContentFile(path="STATISTICS.html")
# ContentFile(path="TABLES.html")
# ContentFile(path="TEST_Echart_1.html")
# ContentFile(path="Word_Cloud_Line.py")
# ContentFile(path="_config.yml")
# ContentFile(path="billboard.html")
# ContentFile(path="billboard.min.css")
# ContentFile(path="billboard.pkgd.min.js")
# ContentFile(path="echarts.js")
# ContentFile(path="echarts.min.js")
# ContentFile(path="index.html")
# ContentFile(path="minicheck_result.txt")
# ContentFile(path="minicheck_tes.txt")
# ContentFile(path="minicheck_test.txt")
# ContentFile(path="minicheck_test_1.txt")
# ContentFile(path="minicheck_test_2.txt")
# ContentFile(path="render.html")
# ContentFile(path="test.html")
# ContentFile(path="test.txt")
# ContentFile(path="test_another.html")
# ContentFile(path="venv")
# License:
#     <html>
#       <meta charset="utf-8">
#       <head><title>HTML Pandas Dataframe with CSS</title></head>
#       <link rel="stylesheet" type="text/css" href="billboard.min.css"/>
#       <body>
#         <table border="1" class="dataframe mystyle">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>Category</th>
#       <th>DESCRIPTION</th>
#       <th>VALUE</th>
#       <th>CHECK</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>336</th>
#       <td>LICENSE</td>
#       <td>License usage (%)</td>
#       <td>171</td>
#       <td>NOT OK</td>
#     </tr>
#   </tbody>
# </table>
#       </body>
#     </html>
#
# ====================================================================================================
# ############### 5
# Full name: stockpy/stockpy.github.io
# Description: None
# Date created: 2020-05-05 02:13:08
# Date of last push: 2020-12-24 05:54:52
# Home Page: None
# Language: Python
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# Contents:
# ContentFile(path="20200831.html")
# ContentFile(path="ADMINISTRATION.html")
# ContentFile(path="APPLICATION.html")
# ContentFile(path="BACKUP.html")
# ContentFile(path="BBA.html")
# ContentFile(path="BB_ADMINISTRATION.html")
# ContentFile(path="BB_APPLICATION.html")
# ContentFile(path="BB_BACKUP.html")
# ContentFile(path="BB_ColTotal.html")
# ContentFile(path="BB_DISKS.html")
# ContentFile(path="BB_LICENSE.html")
# ContentFile(path="BB_LOCKS.html")
# ContentFile(path="BB_MEMORY.html")
# ContentFile(path="BB_Main.html")
# ContentFile(path="BB_MiniCheck_Inform.html")
# ContentFile(path="BB_OBJECTS.html")
# ContentFile(path="BB_OPERATION SYSTEM.html")
# ContentFile(path="BB_OPERATION_SYSTEM.html")
# ContentFile(path="BB_OPRATION_SYSTEM.html")
# ContentFile(path="BB_One.html")
# ContentFile(path="BB_SQL.html")
# ContentFile(path="BB_STATISTICS.html")
# ContentFile(path="BB_TABLES.html")
# ContentFile(path="BB_전 체.html")
# ContentFile(path="DISKS.html")
# ContentFile(path="D_\Python\Log\Profit_20201223.html")
# ContentFile(path="Echart_ADMINISTRATION.html")
# ContentFile(path="Echart_APPLICATION.html")
# ContentFile(path="Echart_BACKUP.html")
# ContentFile(path="Echart_DISKS.html")
# ContentFile(path="Echart_LICENSE.html")
# ContentFile(path="Echart_LOCKS.html")
# ContentFile(path="Echart_MEMORY.html")
# ContentFile(path="Echart_OBJECTS.html")
# ContentFile(path="Echart_OPERATION SYSTEM.html")
# ContentFile(path="Echart_SQL.html")
# ContentFile(path="Echart_STATISTICS.html")
# ContentFile(path="Echart_TABLES.html")
# ContentFile(path="Echart_Test.html")
# ContentFile(path="Echart_Test_1.html")
# ContentFile(path="Hot_Spot.html")
# ContentFile(path="LICENSE.html")
# ContentFile(path="LOCKS.html")
# ContentFile(path="MEMORY.html")
# ContentFile(path="MiniCheck.py")
# ContentFile(path="MiniCheck_BB.py")
# ContentFile(path="MiniCheck_Inform.html")
# ContentFile(path="OBJECTS.html")
# ContentFile(path="OPRATION_SYSTEM.html")
# ContentFile(path="Porfit_20200925.html")
# ContentFile(path="Porfit_20200928.html")
# ContentFile(path="Porfit_20200929.html")
# ContentFile(path="Profit_20200905.html")
# ContentFile(path="Profit_20200906.html")
# ContentFile(path="Profit_20201006.html")
# ContentFile(path="Profit_20201007.html")
# ContentFile(path="Profit_20201008.html")
# ContentFile(path="Profit_20201012.html")
# ContentFile(path="Profit_20201013.html")
# ContentFile(path="Profit_20201015.html")
# ContentFile(path="Profit_20201016.html")
# ContentFile(path="Profit_20201020.html")
# ContentFile(path="Profit_20201021.html")
# ContentFile(path="Profit_20201022.html")
# ContentFile(path="Profit_20201023.html")
# ContentFile(path="Profit_20201027.html")
# ContentFile(path="Profit_20201028.html")
# ContentFile(path="Profit_20201029.html")
# ContentFile(path="Profit_20201030.html")
# ContentFile(path="Profit_20201102.html")
# ContentFile(path="Profit_20201103.html")
# ContentFile(path="Profit_20201104.html")
# ContentFile(path="Profit_20201105.html")
# ContentFile(path="Profit_20201109.html")
# ContentFile(path="Profit_20201111.html")
# ContentFile(path="Profit_20201112.html")
# ContentFile(path="Profit_20201113.html")
# ContentFile(path="Profit_20201223.html")
# ContentFile(path="README.md")
# ContentFile(path="SQL.html")
# ContentFile(path="STATISTICS.html")
# ContentFile(path="TABLES.html")
# ContentFile(path="TEST_Echart_1.html")
# ContentFile(path="Word_Cloud_Line.py")
# ContentFile(path="_config.yml")
# ContentFile(path="billboard.html")
# ContentFile(path="billboard.min.css")
# ContentFile(path="billboard.pkgd.min.js")
# ContentFile(path="echarts.js")
# ContentFile(path="echarts.min.js")
# ContentFile(path="index.html")
# ContentFile(path="minicheck_result.txt")
# ContentFile(path="minicheck_tes.txt")
# ContentFile(path="minicheck_test.txt")
# ContentFile(path="minicheck_test_1.txt")
# ContentFile(path="minicheck_test_2.txt")
# ContentFile(path="render.html")
# ContentFile(path="test.html")
# ContentFile(path="test.txt")
# ContentFile(path="test_another.html")
# ContentFile(path="venv")
# License:
#     <html>
#       <meta charset="utf-8">
#       <head><title>HTML Pandas Dataframe with CSS</title></head>
#       <link rel="stylesheet" type="text/css" href="billboard.min.css"/>
#       <body>
#         <table border="1" class="dataframe mystyle">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>Category</th>
#       <th>DESCRIPTION</th>
#       <th>VALUE</th>
#       <th>CHECK</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>336</th>
#       <td>LICENSE</td>
#       <td>License usage (%)</td>
#       <td>171</td>
#       <td>NOT OK</td>
#     </tr>
#   </tbody>
# </table>
#       </body>
#     </html>
#
# ############### 6
# ---------------------------------------------------------------------------
# UnknownObjectException                    Traceback (most recent call last)
# <ipython-input-7-9b2de466232b> in <module>
#      73 time.sleep(1)
#      74 # create a file and commit n push
# ---> 75 repo.create_file("Stock_202011125.html", "commit message", "Stock_202011125.html-- TEST")
#      76 print("############### 7")
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Repository.py in create_file(self, path, message, content, branch, committer, author)
#    2030             "PUT",
#    2031             self.url + "/contents/" + urllib.parse.quote(path),
# -> 2032             input=put_parameters,
#    2033         )
#    2034
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# UnknownObjectException: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#create-or-update-file-contents"}

# %%
import base64
from github import Github
from github import InputGitTreeElement
import datetime, time# for sleep

github_user = "stockpy"
github_password = "Dlfdltka123!"
g = Github(github_user,github_password)

user = g.get_user(github_user)

for repo in user.get_repos():
    repo = repo
    
file_list = [
    'D:\\Python\\Log\\NB_20200906.html'
]

file_names = [
    'NB_20200906.html'
]
# NB file 의 경우 에러 발생 : UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 287737: illegal multibyte sequence

_Name = datetime.datetime.today().strftime("_%Y%m%d")
    
commit_message = 'python update 2'
master_ref = repo.get_git_ref('heads/master')
master_sha = master_ref.object.sha
base_tree = repo.get_git_tree(master_sha)
element_list = list()
for i, entry in enumerate(file_list):
    with open(entry) as input_file:
        print(entry)
        data = input_file.read()
    if entry.endswith('.png') :
        data = base64.b64encode(data)
    element = InputGitTreeElement(file_names[i], '100644', 'blob', data)
    element_list.append(element)
tree = repo.create_git_tree(element_list, base_tree)
parent = repo.get_git_commit(master_sha)
commit = repo.create_git_commit(commit_message, tree, [parent])
master_ref.edit(commit.sha)
# Out:
# D:\Python\Log\NB_20200906.html
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-e0d7d2f73c0c> in <module>
#      32     with open(entry) as input_file:
#      33         print(entry)
# ---> 34         data = input_file.read()
#      35     if entry.endswith('.png') :
#      36         data = base64.b64encode(data)
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 287737: illegal multibyte sequence

# %%
import requests
import base64

username = 'stockpy'
token = 'e283d417face50d97a0cfdb81095a36d60683385'

login = requests.get('https://api.github.com/search/repositories?q=github+api', auth=(username,token))

print(login)

headers = {'Authorization': 'token ' + token}

login = requests.get('https://api.github.com/user', headers=headers)
print(login.json())

# delete REPO
repo = 'some_repo' # Delete this repo

headers = {'Authorization': 'token ' + token}

login = requests.delete('https://api.github.com/' + 'repos/' + username + '/' + repo, headers=headers)

# create REPO
repo = 'some_repo'
description = 'Created with api'

payload = {'name': repo, 'description': description, 'auto_init': 'true'}

login = requests.post('http://stockpy.github.io/' + 'user/repos', auth=(user,token), data=json.dumps(payload))
# Out:
# <Response [200]>
# {'login': 'stockpy', 'id': 64298149, 'node_id': 'MDQ6VXNlcjY0Mjk4MTQ5', 'avatar_url': 'https://avatars.githubusercontent.com/u/64298149?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/stockpy', 'html_url': 'https://github.com/stockpy', 'followers_url': 'https://api.github.com/users/stockpy/followers', 'following_url': 'https://api.github.com/users/stockpy/following{/other_user}', 'gists_url': 'https://api.github.com/users/stockpy/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/stockpy/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/stockpy/subscriptions', 'organizations_url': 'https://api.github.com/users/stockpy/orgs', 'repos_url': 'https://api.github.com/users/stockpy/repos', 'events_url': 'https://api.github.com/users/stockpy/events{/privacy}', 'received_events_url': 'https://api.github.com/users/stockpy/received_events', 'type': 'User', 'site_admin': False, 'name': None, 'company': None, 'blog': '', 'location': None, 'email': None, 'hireable': None, 'bio': None, 'twitter_username': None, 'public_repos': 1, 'public_gists': 1, 'followers': 0, 'following': 0, 'created_at': '2020-04-25T04:39:49Z', 'updated_at': '2021-02-25T12:43:25Z'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b2f45d5c09b1> in <module>
#      27 payload = {'name': repo, 'description': description, 'auto_init': 'true'}
#      28
# ---> 29 login = requests.post('http://stockpy.github.io/' + 'user/repos', auth=(user,token), data=json.dumps(payload))
#
# NameError: name 'json' is not defined

# %%
# 실제 되던 GITHUB
import base64
from github import Github
from github import InputGitTreeElement
import datetime, time# for sleep

def __Github_Upload() :
    
    Github_user = "stockpy"
    Github_password = "Dlfdltka123!"
    
    g = Github(Github_user,Github_password)

    user = g.get_user(Github_user)

    for repo in user.get_repos():
        repo = repo
        print(repo)

    _Name = datetime.datetime.today().strftime("_%Y%m%d")
    
    file1 = "D:\\Python\\Log\\Money_Flow.html"

    # NB file 의 경우 에러 발생 : UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 287737: illegal multibyte sequence
    file_list = [file1]
    file_names = ["Money_Flow.html"]
    commit_message = 'Stock Python'+_Name

    master_ref = repo.get_git_ref('heads/master')
    master_sha = master_ref.object.sha
    base_tree = repo.get_git_tree(master_sha)
    
    print(base_tree)
    
    element_list = list()
    for i, entry in enumerate(file_list):
        with open(entry) as input_file:
            print(input_file)
            data = input_file.read()
        if entry.endswith('.png'):
            data = base64.b64encode(data)
        element = InputGitTreeElement(file_names[i], '100644', 'blob', data)
        element_list.append(element)

    print(element_list)
    
    tree = repo.create_git_tree(element_list, base_tree)
    parent = repo.get_git_commit(master_sha)
    commit = repo.create_git_commit(commit_message, tree, [parent])
    master_ref.edit(commit.sha)
    
if __name__ == '__main__' :
    __Github_Upload()
# Out:
# Repository(full_name="stockpy/stockpy")
# Repository(full_name="stockpy/stockpy.github.io")
# Repository(full_name="stockpy/Work")
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# <ipython-input-2-ef3fc3e10da4> in <module>
#      51
#      52 if __name__ == '__main__' :
# ---> 53     __Github_Upload()
#
# <ipython-input-2-ef3fc3e10da4> in __Github_Upload()
#      27     commit_message = 'Stock Python'+_Name
#      28
# ---> 29     master_ref = repo.get_git_ref('heads/master')
#      30     master_sha = master_ref.object.sha
#      31     base_tree = repo.get_git_tree(master_sha)
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Repository.py in get_git_ref(self, ref)
#    2287         assert isinstance(ref, str), ref
#    2288         headers, data = self._requester.requestJsonAndCheck(
# -> 2289             "GET", self.url + prefix + ref
#    2290         )
#    2291         return github.GitRef.GitRef(self._requester, headers, data, completed=True)
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# GithubException: 409 {"message": "Git Repository is empty.", "documentation_url": "https://docs.github.com/enterprise/2.18/user/rest/reference/git#get-a-reference"}

# %%
import requests
from pprint import pprint
from github import Github

# github username
username = "stockpy"
# url to request
url = f"https://api.github.com/users/{username}"
# make the request and return the json
user_data = requests.get(url).json()
# pretty print JSON data
pprint(user_data)

print("################")
# pygithub object
g = Github()
# get that user by username
user = g.get_user(username)

for repo in user.get_repos():
    print(repo)

print("################")
    
username = "stockpy"
password = "Dlfdltka123!"

# authenticate to github
g = Github(username, password)
# get the authenticated user
user = g.get_user()
for repo in user.get_repos():
    print_repo(repo)
    
print("################")

# searching for my repository
repo = g.search_repositories("pythoncode tutorials")[0]

# create a file and commit n push
repo.create_file("test.txt", "commit message", "content of the file")

# delete that created file
contents = repo.get_contents("test.txt")
repo.delete_file(contents.path, "remove test.txt", contents.sha)
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/64298149?v=4',
#  'bio': None,
#  'blog': '',
#  'company': None,
#  'created_at': '2020-04-25T04:39:49Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/stockpy/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/stockpy/followers',
#  'following': 0,
#  'following_url': 'https://api.github.com/users/stockpy/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/stockpy/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/stockpy',
#  'id': 64298149,
#  'location': None,
#  'login': 'stockpy',
#  'name': None,
#  'node_id': 'MDQ6VXNlcjY0Mjk4MTQ5',
#  'organizations_url': 'https://api.github.com/users/stockpy/orgs',
#  'public_gists': 1,
#  'public_repos': 1,
#  'received_events_url': 'https://api.github.com/users/stockpy/received_events',
#  'repos_url': 'https://api.github.com/users/stockpy/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/stockpy/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/stockpy/subscriptions',
#  'twitter_username': None,
#  'type': 'User',
#  'updated_at': '2021-02-25T12:43:25Z',
#  'url': 'https://api.github.com/users/stockpy'}
# ################
# Repository(full_name="stockpy/stockpy.github.io")
# ################
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# <ipython-input-6-995b4dbbe9a9> in <module>
#      30 # get the authenticated user
#      31 user = g.get_user()
# ---> 32 for repo in user.get_repos():
#      33     print_repo(repo)
#      34
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\PaginatedList.py in __iter__(self)
#      57             yield element
#      58         while self._couldGrow():
# ---> 59             newElements = self._grow()
#      60             for element in newElements:
#      61                 yield element
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\PaginatedList.py in _grow(self)
#      69
#      70     def _grow(self):
# ---> 71         newElements = self._fetchNextPage()
#      72         self.__elements += newElements
#      73         return newElements
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\PaginatedList.py in _fetchNextPage(self)
#     202     def _fetchNextPage(self):
#     203         headers, data = self.__requester.requestJsonAndCheck(
# --> 204             "GET", self.__nextUrl, parameters=self.__nextParams, headers=self.__headers
#     205         )
#     206         data = data if data else []
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# GithubException: 401 {"message": "Requires authentication", "documentation_url": "https://docs.github.com/rest/reference/repos#list-repositories-for-the-authenticated-user"}

# %%
from github import Github
g = Github("stockpy", "Dlfdltka123!")

repo = g.get_user().get_repo(GITHUB_REPO)
all_files = []
contents = repo.get_contents("")
while contents:
    file_content = contents.pop(0)
    if file_content.type == "dir":
        contents.extend(repo.get_contents(file_content.path))
    else:
        file = file_content
        all_files.append(str(file).replace('ContentFile(path="','').replace('")',''))

with open('/tmp/file.txt', 'r') as file:
    content = file.read()

# Upload to github
git_prefix = 'folder1/'
git_file = git_prefix + 'file.txt'
if git_file in all_files:
    contents = repo.get_contents(git_file)
    repo.update_file(contents.path, "committing files", content, contents.sha, branch="master")
    print(git_file + ' UPDATED')
else:
    repo.create_file(git_file, "committing files", content, branch="master")
    print(git_file + ' CREATED')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97301376f0d4> in <module>
#       2 g = Github("stockpy", "Dlfdltka123!")
#       3
# ----> 4 repo = g.get_user().get_repo(GITHUB_REPO)
#       5 all_files = []
#       6 contents = repo.get_contents("")
#
# NameError: name 'GITHUB_REPO' is not defined
