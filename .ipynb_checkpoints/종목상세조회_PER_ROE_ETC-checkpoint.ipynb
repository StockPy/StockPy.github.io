# %%
import os
import win32com.client
import pythoncom
import datetime, time
import sys

from init_test import *

##################################################
def __Init_Conn() :

    class XASessionEventHandler:
        login_state = 0

        def OnLogin(self, code, msg):
            if code == "0000":
                print("로그인 성공")
                XASessionEventHandler.login_state = 1
            else:
                print("로그인 실패")

    instXASession = win32com.client.DispatchWithEvents("XA_Session.XASession", XASessionEventHandler)

    instXASession.ConnectServer(Server_Name, 20001)
    instXASession.Login(id, passwd, cert_passwd, 0, 0)

    while XASessionEventHandler.login_state == 0:
        pythoncom.PumpWaitingMessages()

    num_account = instXASession.GetAccountListCount()
    for i in range(num_account):
        account = instXASession.GetAccountList(i)
        print("계좌번호 : %s" % (account))
        
##################################################
def __Check_Account() :

    # 주식잔고 조회2
    class XAQueryEventHandlerT0424:
        query_state = 0

        def OnReceiveData(self, code):
            XAQueryEventHandlerT0424.query_state = 1

    instXAQueryT0424 = win32com.client.DispatchWithEvents("XA_DataSet.XAQuery", XAQueryEventHandlerT0424)
    instXAQueryT0424.ResFileName = "C:\\eBEST\\xingAPI\\Res\\t0424.res"

    instXAQueryT0424.SetFieldData("t0424InBlock", "accno", 0, Account_No) # XAQuery 인스턴스를 통해 SetFieldData라는 메서드를 호출한 후 적절한 인자 값을 지정
    instXAQueryT0424.SetFieldData("t0424InBlock", "passwd", 0, Account_PWD)
    instXAQueryT0424.Request(0) # Request 메서드를 호출해서 입력 데이터를 서버로 전송

    while XAQueryEventHandlerT0424.query_state == 0: # 서버에 TR 요청을 했다면 해당 작업이 완료됐다는 이벤트를 받을 때까지 프로그램이 종료되지 않고 대기
        pythoncom.PumpWaitingMessages()
        # 이베스트투자증권의 서버는 TR 처리가 완료되면 OnReceiveData 메서드를 콜백합니다.
        # 이로 인해 XAQueryEventHandlerT1102.query_state 값이 1로 변경되어 이벤트 대기 루프에서 exit

    count1 = instXAQueryT0424.GetBlockCount("t0424OutBlock1")
    print(count1)

    for i in range(count1):
        expcode = instXAQueryT0424.GetFieldData("t0424OutBlock1", "expcode", i)
        hname = instXAQueryT0424.GetFieldData("t0424OutBlock1", "hname", i) # 종목명
        janqty = instXAQueryT0424.GetFieldData("t0424OutBlock1", "janqty", i) # 잔고수량
        mdposqt = instXAQueryT0424.GetFieldData("t0424OutBlock1", "mdposqt", i) # 매도 가능수량
        pamt = instXAQueryT0424.GetFieldData("t0424OutBlock1", "pamt", i) # 평균단가
        mamt = instXAQueryT0424.GetFieldData("t0424OutBlock1", "mamt", i) # 매입금액
        appamt = instXAQueryT0424.GetFieldData("t0424OutBlock1", "appamt", i) # 평가금액
        dtsunik = instXAQueryT0424.GetFieldData("t0424OutBlock1", "dtsunik", i) # 평가손익
        sunikrt = instXAQueryT0424.GetFieldData("t0424OutBlock1", "sunikrt", i) # 수익율
        print("종목번호 : %s, 종목명 : %s, 잔고수량 : %s, 평단 : %s, 매입액 : %s, 손액 : %s, 손익 : %s" % (expcode, hname, janqty, pamt, mamt, dtsunik, sunikrt))

################################################## 
# 주문 내역이 있는지 확인하는 Function : 없으면 CallNothing 0를 return
def __Call_Check() :
    print("# Call_Check Start : %s" % (datetime.datetime.today().strftime("%H:%M:%S")))
    time.sleep(1) # 자주 호출하면 먹통이 되는 거 같아서 sleep 추가, CPU Full 도 이것때문 (2020.07.16)
    ##################################################
    
    # 주식체결 조회2
    class XAQueryEventHandlerT0425:
        query_state = 0

        def OnReceiveData(self, code):
            XAQueryEventHandlerT0425.query_state = 1

    instXAQueryT0425 = win32com.client.DispatchWithEvents("XA_DataSet.XAQuery", XAQueryEventHandlerT0425)
    instXAQueryT0425.ResFileName = "C:\\eBEST\\xingAPI\\Res\\t0425.res"
    instXAQueryT0425.SetFieldData("t0425InBlock", "accno", 0, Account_No) # XAQuery 인스턴스를 통해 SetFieldData라는 메서드를 호출한 후 적절한 인자 값을 지정
    instXAQueryT0425.SetFieldData("t0425InBlock", "passwd", 0, Account_PWD)
#     instXAQueryT0425.SetFieldData("t0425InBlock", "expcode", 0, Target_Expcode)
    instXAQueryT0425.SetFieldData("t0425InBlock", "sortgb", 0, 1) # sorting, 매매구분 정보를 넣어야 for문으로 전체 리스트 가져온다
    instXAQueryT0425.SetFieldData("t0425InBlock", "medosu", 0, 0) # sorting, 매매구분 정보를 넣어야 for문으로 전체 리스트 가져온다, 0 : 전체, 1 : 매도, 2 : 매수
    
    instXAQueryT0425.Request(0) # Request 메서드를 호출해서 입력 데이터를 서버로 전송

    while XAQueryEventHandlerT0425.query_state == 0: # 서버에 TR 요청을 했다면 해당 작업이 완료됐다는 이벤트를 받을 때까지 프로그램이 종료되지 않고 대기
        pythoncom.PumpWaitingMessages()
        # 이베스트투자증권의 서버는 TR 처리가 완료되면 OnReceiveData 메서드를 콜백합니다.
        # 이로 인해 XAQueryEventHandlerT1102.query_state 값이 1로 변경되어 이벤트 대기 루프에서 exit

    count = instXAQueryT0425.GetBlockCount("t0425OutBlock")
#     print("Block Count : %s" % (count)) # ---> 여기서 0 체크해도 될듯
    tqty = instXAQueryT0425.GetFieldData("t0425OutBlock", "tqty", 0) # 총 주문수량
    tcheqty = instXAQueryT0425.GetFieldData("t0425OutBlock", "tcheqty", 0) # 총 체결수량
    tamt = instXAQueryT0425.GetFieldData("t0425OutBlock", "tamt", 0) # 총 주문금액
    tmsamt = instXAQueryT0425.GetFieldData("t0425OutBlock", "tmsamt", 0) # 총 매수체결액
    tmdamt = instXAQueryT0425.GetFieldData("t0425OutBlock", "tmdamt", 0) # 총 매도체결액
    print("총 주문수량 : %s, 총 체결수량 : %s, 총 주문금액 : %s, 총 매수액 : %s, 총 매도액 : %s" % (tqty, tcheqty, tamt, tmsamt, tmdamt))

    count1 = instXAQueryT0425.GetBlockCount("t0425OutBlock1")
    print("Block Count : %s" % (count1))
    account_expcode, order_group_list, order_status_list = [], [], []

    for i in range(count1):
        ordno = instXAQueryT0425.GetFieldData("t0425OutBlock1", "ordno", i) # 주문번호
        expcode = instXAQueryT0425.GetFieldData("t0425OutBlock1", "expcode", i) # 종목번호
        medosu = instXAQueryT0425.GetFieldData("t0425OutBlock1", "medosu", i) # 구분 0 : 전체, 1 : 매도, 2 : 매수
        qty = instXAQueryT0425.GetFieldData("t0425OutBlock1", "qty", i) # 주문수량
        price = instXAQueryT0425.GetFieldData("t0425OutBlock1", "price", i) # 주문가격
        cheqty = instXAQueryT0425.GetFieldData("t0425OutBlock1", "cheqty", i) # 체결수량
        cheprice = instXAQueryT0425.GetFieldData("t0425OutBlock1", "cheprice", i) # 체결가격
        ordrem = instXAQueryT0425.GetFieldData("t0425OutBlock1", "ordrem", i) # 미체결 잔량
        cfmqty = instXAQueryT0425.GetFieldData("t0425OutBlock1", "cfmqty", i) # 확인 수량
        status = instXAQueryT0425.GetFieldData("t0425OutBlock1", "status", i) # 상태
        ordtime = instXAQueryT0425.GetFieldData("t0425OutBlock1", "ordtime", i) # 상태
        print("주문번호 : %s, 종목번호 : %s, 구분 : %s, 주문수량 : %s, 가격 : %s, 체결수량 : %s, 잔량 : %s, 상태 : %s, 시간 : %s" % (ordno, expcode, medosu, qty, price, cheqty, ordrem, status, ordtime))
    print("# Call_Check End : %s" % (datetime.datetime.today().strftime("%H:%M:%S")))
    
    instXAQueryT0425.close()
    
   
if __name__ == '__main__' :
    print("# Init Connection")
    __Init_Conn()
    print("# Check Account")
    __Check_Account()
    print("# Check Trade")
    __Call_Check()
    print("# Check Money Flow")
    __Check_Money_Flow()
    print("# END")
# Out:
# # Init Connection
# 로그인 성공
# 계좌번호 : 55501053242
# # Check Account
# 6
# 종목번호 : 123320, 종목명 : TIGER 레버리지, 잔고수량 : 13, 평단 : 14730, 매입액 : 191490, 손액 : -8918, 손익 : -4.64
# 종목번호 : 204450, 종목명 : KODEX China H 레버리, 잔고수량 : 177, 평단 : 6708, 매입액 : 1187425, 손액 : -31878, 손익 : -2.67
# 종목번호 : 204480, 종목명 : TIGER 차이나CSI300레, 잔고수량 : 33, 평단 : 26256, 매입액 : 866470, 손액 : 31041, 손익 : 3.56
# 종목번호 : 225040, 종목명 : TIGER 미국S&P500레버, 잔고수량 : 15, 평단 : 19610, 매입액 : 294150, 손액 : 16477, 손익 : 5.58
# 종목번호 : 233160, 종목명 : TIGER 코스닥150 레버, 잔고수량 : 136, 평단 : 14315, 매입액 : 1946925, 손액 : -80797, 손익 : -4.13
# 종목번호 : 236350, 종목명 : TIGER 인도니프티50레, 잔고수량 : 62, 평단 : 11488, 매입액 : 712305, 손액 : 46369, 손익 : 6.48
# # Check Trade
# # Call_Check Start : 22:29:19
# 총 주문수량 : , 총 체결수량 : , 총 주문금액 : , 총 매수액 : , 총 매도액 :
# Block Count : 0
# # Call_Check End : 22:29:20
# # Check Money Flow
# TEST
# 300
# 날짜 : 20200821, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 523373, 미수금 : 3251, 신용잔고 : 157668, 주식볼륨 : 730549
#
# 날짜 : 20200820, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 526393, 미수금 : 4323, 신용잔고 : 157949, 주식볼륨 : 726071
#
# 날짜 : 20200819, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 515925, 미수금 : 3662, 신용잔고 : 160324, 주식볼륨 : 731779
#
# 날짜 : 20200818, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 514557, 미수금 : 3504, 신용잔고 : 160326, 주식볼륨 : 730095
#
# 날짜 : 20200814, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 507922, 미수금 : 3681, 신용잔고 : 159001, 주식볼륨 : 732505
#
# 날짜 : 20200813, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 511469, 미수금 : 3029, 신용잔고 : 157940, 주식볼륨 : 738612
#
# 날짜 : 20200812, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 502996, 미수금 : 3040, 신용잔고 : 156287, 주식볼륨 : 738989
#
# 날짜 : 20200811, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 507264, 미수금 : 2921, 신용잔고 : 153805, 주식볼륨 : 738183
#
# 날짜 : 20200810, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 511263, 미수금 : 2973, 신용잔고 : 151727, 주식볼륨 : 739376
#
# 날짜 : 20200807, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 492196, 미수금 : 2842, 신용잔고 : 150538, 주식볼륨 : 735283
#
# 날짜 : 20200806, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 488749, 미수금 : 3255, 신용잔고 : 148147, 주식볼륨 : 737182
#
# 날짜 : 20200805, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 480563, 미수금 : 2919, 신용잔고 : 146670, 주식볼륨 : 735214
#
# 날짜 : 20200804, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 492346, 미수금 : 2487, 신용잔고 : 145447, 주식볼륨 : 735377
#
# 날짜 : 20200803, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 503546, 미수금 : 2535, 신용잔고 : 144208, 주식볼륨 : 734761
#
# 날짜 : 20200731, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 477863, 미수금 : 2686, 신용잔고 : 143259, 주식볼륨 : 735632
#
# 날짜 : 20200730, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 476458, 미수금 : 2816, 신용잔고 : 142120, 주식볼륨 : 737752
#
# 날짜 : 20200729, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 474484, 미수금 : 3171, 신용잔고 : 140577, 주식볼륨 : 737468
#
# 날짜 : 20200728, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 469753, 미수금 : 3391, 신용잔고 : 139537, 주식볼륨 : 737942
#
# 날짜 : 20200727, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 473285, 미수금 : 3470, 신용잔고 : 140302, 주식볼륨 : 732151
#
# 날짜 : 20200724, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 471063, 미수금 : 3071, 신용잔고 : 140496, 주식볼륨 : 732841
#
# 날짜 : 20200723, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 466771, 미수금 : 2879, 신용잔고 : 138623, 주식볼륨 : 735156
#
# 날짜 : 20200722, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 459081, 미수금 : 2788, 신용잔고 : 137679, 주식볼륨 : 735542
#
# 날짜 : 20200721, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 461565, 미수금 : 2486, 신용잔고 : 136690, 주식볼륨 : 738016
#
# 날짜 : 20200720, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 455338, 미수금 : 2877, 신용잔고 : 135681, 주식볼륨 : 735499
#
# 날짜 : 20200717, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 457149, 미수금 : 2800, 신용잔고 : 135358, 주식볼륨 : 734962
#
# 날짜 : 20200716, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 453978, 미수금 : 2556, 신용잔고 : 135170, 주식볼륨 : 730962
#
# 날짜 : 20200715, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 454727, 미수금 : 2533, 신용잔고 : 134162, 주식볼륨 : 736322
#
# 날짜 : 20200714, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 455515, 미수금 : 2593, 신용잔고 : 132996, 주식볼륨 : 732723
#
# 날짜 : 20200713, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 466011, 미수금 : 2478, 신용잔고 : 132014, 주식볼륨 : 735582
#
# 날짜 : 20200710, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 460337, 미수금 : 2714, 신용잔고 : 130923, 주식볼륨 : 734070
#
# 날짜 : 20200709, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 463415, 미수금 : 2854, 신용잔고 : 129820, 주식볼륨 : 738037
#
# 날짜 : 20200708, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 466204, 미수금 : 2670, 신용잔고 : 128574, 주식볼륨 : 738161
#
# 날짜 : 20200707, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 461772, 미수금 : 2508, 신용잔고 : 127036, 주식볼륨 : 739433
#
# 날짜 : 20200706, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 456040, 미수금 : 2610, 신용잔고 : 126230, 주식볼륨 : 743648
#
# 날짜 : 20200703, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 455799, 미수금 : 2842, 신용잔고 : 126376, 주식볼륨 : 739860
#
# 날짜 : 20200702, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 473213, 미수금 : 2727, 신용잔고 : 126705, 주식볼륨 : 739715
#
# 날짜 : 20200701, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 478636, 미수금 : 2831, 신용잔고 : 126472, 주식볼륨 : 737730
#
# 날짜 : 20200630, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 461819, 미수금 : 2637, 신용잔고 : 126604, 주식볼륨 : 738516
#
# 날짜 : 20200629, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 468439, 미수금 : 3089, 신용잔고 : 126624, 주식볼륨 : 736723
#
# 날짜 : 20200626, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 505095, 미수금 : 3015, 신용잔고 : 125452, 주식볼륨 : 742988
#
# 날짜 : 20200625, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 463392, 미수금 : 4264, 신용잔고 : 124357, 주식볼륨 : 735904
#
# 날짜 : 20200624, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 461448, 미수금 : 2652, 신용잔고 : 123294, 주식볼륨 : 741895
#
# 날짜 : 20200623, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 473872, 미수금 : 2494, 신용잔고 : 121983, 주식볼륨 : 737825
#
# 날짜 : 20200622, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 472615, 미수금 : 2616, 신용잔고 : 120962, 주식볼륨 : 736862
#
# 날짜 : 20200619, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 460930, 미수금 : 2900, 신용잔고 : 119667, 주식볼륨 : 737271
#
# 날짜 : 20200618, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 463160, 미수금 : 3165, 신용잔고 : 117701, 주식볼륨 : 735638
#
# 날짜 : 20200617, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 462280, 미수금 : 4519, 신용잔고 : 118386, 주식볼륨 : 734723
#
# 날짜 : 20200616, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 480730, 미수금 : 3505, 신용잔고 : 120262, 주식볼륨 : 733362
#
# 날짜 : 20200615, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 482068, 미수금 : 3588, 신용잔고 : 120598, 주식볼륨 : 722940
#
# 날짜 : 20200612, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 477691, 미수금 : 2823, 신용잔고 : 118628, 주식볼륨 : 737973
#
# 날짜 : 20200611, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 458461, 미수금 : 2986, 신용잔고 : 117909, 주식볼륨 : 744205
#
# 날짜 : 20200610, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 465950, 미수금 : 2470, 신용잔고 : 116471, 주식볼륨 : 750824
#
# 날짜 : 20200609, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 453723, 미수금 : 2121, 신용잔고 : 115109, 주식볼륨 : 757284
#
# 날짜 : 20200608, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 455691, 미수금 : 2501, 신용잔고 : 113777, 주식볼륨 : 761903
#
# 날짜 : 20200605, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 445552, 미수금 : 2544, 신용잔고 : 113163, 주식볼륨 : 765482
#
# 날짜 : 20200604, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 446445, 미수금 : 2444, 신용잔고 : 112032, 주식볼륨 : 765836
#
# 날짜 : 20200603, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 440249, 미수금 : 2481, 신용잔고 : 110467, 주식볼륨 : 766391
#
# 날짜 : 20200602, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 435372, 미수금 : 2819, 신용잔고 : 109385, 주식볼륨 : 760802
#
# 날짜 : 20200601, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 443490, 미수금 : 3024, 신용잔고 : 109315, 주식볼륨 : 758263
#
# 날짜 : 20200529, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 438409, 미수금 : 2736, 신용잔고 : 109276, 주식볼륨 : 755126
#
# 날짜 : 20200528, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 445794, 미수금 : 3129, 신용잔고 : 108073, 주식볼륨 : 753745
#
# 날짜 : 20200527, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 439547, 미수금 : 2273, 신용잔고 : 106662, 주식볼륨 : 754117
#
# 날짜 : 20200526, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 441181, 미수금 : 2433, 신용잔고 : 105869, 주식볼륨 : 753392
#
# 날짜 : 20200525, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 437962, 미수금 : 2350, 신용잔고 : 104645, 주식볼륨 : 749951
#
# 날짜 : 20200522, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 436431, 미수금 : 2317, 신용잔고 : 103069, 주식볼륨 : 748236
#
# 날짜 : 20200521, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 433875, 미수금 : 2795, 신용잔고 : 102248, 주식볼륨 : 751631
#
# 날짜 : 20200520, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 424126, 미수금 : 2795, 신용잔고 : 102115, 주식볼륨 : 754078
#
# 날짜 : 20200519, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 426279, 미수금 : 2761, 신용잔고 : 101410, 주식볼륨 : 752831
#
# 날짜 : 20200518, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 422716, 미수금 : 3965, 신용잔고 : 100783, 주식볼륨 : 749937
#
# 날짜 : 20200515, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 421956, 미수금 : 2644, 신용잔고 : 99534, 주식볼륨 : 749354
#
# 날짜 : 20200514, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 436583, 미수금 : 2834, 신용잔고 : 98665, 주식볼륨 : 749658
#
# 날짜 : 20200513, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 427302, 미수금 : 2739, 신용잔고 : 97181, 주식볼륨 : 754749
#
# 날짜 : 20200512, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 431833, 미수금 : 2254, 신용잔고 : 95549, 주식볼륨 : 757361
#
# 날짜 : 20200511, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 433315, 미수금 : 2484, 신용잔고 : 94959, 주식볼륨 : 759016
#
# 날짜 : 20200508, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 424756, 미수금 : 2458, 신용잔고 : 94016, 주식볼륨 : 760827
#
# 날짜 : 20200507, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 444689, 미수금 : 2556, 신용잔고 : 92932, 주식볼륨 : 759390
#
# 날짜 : 20200506, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 446731, 미수금 : 2263, 신용잔고 : 91483, 주식볼륨 : 763024
#
# 날짜 : 20200504, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 443872, 미수금 : 2335, 신용잔고 : 91382, 주식볼륨 : 757549
#
# 날짜 : 20200429, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 427263, 미수금 : 2170, 신용잔고 : 90434, 주식볼륨 : 763435
#
# 날짜 : 20200428, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 439729, 미수금 : 2747, 신용잔고 : 89813, 주식볼륨 : 761932
#
# 날짜 : 20200427, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 443101, 미수금 : 2513, 신용잔고 : 88963, 주식볼륨 : 760736
#
# 날짜 : 20200424, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 437030, 미수금 : 2496, 신용잔고 : 87986, 주식볼륨 : 761994
#
# 날짜 : 20200423, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 442470, 미수금 : 2714, 신용잔고 : 86583, 주식볼륨 : 768367
#
# 날짜 : 20200422, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 452051, 미수금 : 2519, 신용잔고 : 85221, 주식볼륨 : 767623
#
# 날짜 : 20200421, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 455013, 미수금 : 2269, 신용잔고 : 83674, 주식볼륨 : 769056
#
# 날짜 : 20200420, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 444347, 미수금 : 2174, 신용잔고 : 82546, 주식볼륨 : 776641
#
# 날짜 : 20200417, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 442617, 미수금 : 2111, 신용잔고 : 81071, 주식볼륨 : 779818
#
# 날짜 : 20200416, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 442345, 미수금 : 2688, 신용잔고 : 80799, 주식볼륨 : 773861
#
# 날짜 : 20200414, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 446845, 미수금 : 2268, 신용잔고 : 79976, 주식볼륨 : 778535
#
# 날짜 : 20200413, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 446395, 미수금 : 2229, 신용잔고 : 78807, 주식볼륨 : 777725
#
# 날짜 : 20200410, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 444261, 미수금 : 2262, 신용잔고 : 77053, 주식볼륨 : 784884
#
# 날짜 : 20200409, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 441643, 미수금 : 2250, 신용잔고 : 75273, 주식볼륨 : 784783
#
# 날짜 : 20200408, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 440840, 미수금 : 2055, 신용잔고 : 73594, 주식볼륨 : 781929
#
# 날짜 : 20200407, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 434090, 미수금 : 2190, 신용잔고 : 72602, 주식볼륨 : 783539
#
# 날짜 : 20200406, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 431790, 미수금 : 2451, 신용잔고 : 71559, 주식볼륨 : 778384
#
# 날짜 : 20200403, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 437305, 미수금 : 2877, 신용잔고 : 70321, 주식볼륨 : 770222
#
# 날짜 : 20200402, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 465676, 미수금 : 2448, 신용잔고 : 68781, 주식볼륨 : 771881
#
# 날짜 : 20200401, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 476669, 미수금 : 2145, 신용잔고 : 66889, 주식볼륨 : 767309
#
# 날짜 : 20200331, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 430829, 미수금 : 2322, 신용잔고 : 65783, 주식볼륨 : 779489
#
# 날짜 : 20200330, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 434584, 미수금 : 3249, 신용잔고 : 65257, 주식볼륨 : 774429
#
# 날짜 : 20200327, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 439772, 미수금 : 2657, 신용잔고 : 64404, 주식볼륨 : 776866
#
# 날짜 : 20200326, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 451690, 미수금 : 2221, 신용잔고 : 64361, 주식볼륨 : 774188
#
# 날짜 : 20200325, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 414359, 미수금 : 2617, 신용잔고 : 64075, 주식볼륨 : 780693
#
# 날짜 : 20200324, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 409912, 미수금 : 2643, 신용잔고 : 64470, 주식볼륨 : 768644
#
# 날짜 : 20200323, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 398667, 미수금 : 3872, 신용잔고 : 67673, 주식볼륨 : 748243
#
# 날짜 : 20200320, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 391219, 미수금 : 2883, 신용잔고 : 75245, 주식볼륨 : 762288
#
# 날짜 : 20200319, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 383667, 미수금 : 3185, 신용잔고 : 78283, 주식볼륨 : 746474
#
# 날짜 : 20200318, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 371126, 미수금 : 3406, 신용잔고 : 81418, 주식볼륨 : 764679
#
# 날짜 : 20200317, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 377409, 미수금 : 3191, 신용잔고 : 85422, 주식볼륨 : 776559
#
# 날짜 : 20200316, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 367189, 미수금 : 3121, 신용잔고 : 94190, 주식볼륨 : 781951
#
# 날짜 : 20200313, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 361901, 미수금 : 2864, 신용잔고 : 98628, 주식볼륨 : 786005
#
# 날짜 : 20200312, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 340793, 미수금 : 2579, 신용잔고 : 100260, 주식볼륨 : 792829
#
# 날짜 : 20200311, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 330242, 미수금 : 2968, 신용잔고 : 101345, 주식볼륨 : 802567
#
# 날짜 : 20200310, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 329093, 미수금 : 2155, 신용잔고 : 101874, 주식볼륨 : 812789
#
# 날짜 : 20200309, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 320974, 미수금 : 1822, 신용잔고 : 101064, 주식볼륨 : 813110
#
# 날짜 : 20200306, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 310516, 미수금 : 1875, 신용잔고 : 100247, 주식볼륨 : 824312
#
# 날짜 : 20200305, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 310261, 미수금 : 2103, 신용잔고 : 99969, 주식볼륨 : 829887
#
# 날짜 : 20200304, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 310734, 미수금 : 2085, 신용잔고 : 99411, 주식볼륨 : 826272
#
# 날짜 : 20200303, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 315697, 미수금 : 2436, 신용잔고 : 100102, 주식볼륨 : 816838
#
# 날짜 : 20200302, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 331815, 미수금 : 2194, 신용잔고 : 102785, 주식볼륨 : 815902
#
# 날짜 : 20200228, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 312124, 미수금 : 2051, 신용잔고 : 103726, 주식볼륨 : 812209
#
# 날짜 : 20200227, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 311691, 미수금 : 2430, 신용잔고 : 102962, 주식볼륨 : 821694
#
# 날짜 : 20200226, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 317498, 미수금 : 2858, 신용잔고 : 103510, 주식볼륨 : 826038
#
# 날짜 : 20200225, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 307128, 미수금 : 2254, 신용잔고 : 104864, 주식볼륨 : 831759
#
# 날짜 : 20200224, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 301229, 미수금 : 2240, 신용잔고 : 105436, 주식볼륨 : 829787
#
# 날짜 : 20200221, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 285916, 미수금 : 2181, 신용잔고 : 105163, 주식볼륨 : 841886
#
# 날짜 : 20200220, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 286180, 미수금 : 2157, 신용잔고 : 105141, 주식볼륨 : 847484
#
# 날짜 : 20200219, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 289156, 미수금 : 1999, 신용잔고 : 104627, 주식볼륨 : 850959
#
# 날짜 : 20200218, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 290304, 미수금 : 1968, 신용잔고 : 104052, 주식볼륨 : 847331
#
# 날짜 : 20200217, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 287546, 미수금 : 2168, 신용잔고 : 103510, 주식볼륨 : 853408
#
# 날짜 : 20200214, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 283212, 미수금 : 1862, 신용잔고 : 102950, 주식볼륨 : 858343
#
# 날짜 : 20200213, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 301122, 미수금 : 1789, 신용잔고 : 102313, 주식볼륨 : 857753
#
# 날짜 : 20200212, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 283694, 미수금 : 1935, 신용잔고 : 101821, 주식볼륨 : 859792
#
# 날짜 : 20200211, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 286003, 미수금 : 1869, 신용잔고 : 100851, 주식볼륨 : 860092
#
# 날짜 : 20200210, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 304710, 미수금 : 1903, 신용잔고 : 99411, 주식볼륨 : 856516
#
# 날짜 : 20200207, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 286228, 미수금 : 1865, 신용잔고 : 99415, 주식볼륨 : 858214
#
# 날짜 : 20200206, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 289056, 미수금 : 1862, 신용잔고 : 98532, 주식볼륨 : 861727
#
# 날짜 : 20200205, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 291607, 미수금 : 2092, 신용잔고 : 98182, 주식볼륨 : 856620
#
# 날짜 : 20200204, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 295070, 미수금 : 2334, 신용잔고 : 99149, 주식볼륨 : 855252
#
# 날짜 : 20200203, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 312414, 미수금 : 2500, 신용잔고 : 100380, 주식볼륨 : 847561
#
# 날짜 : 20200131, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 287192, 미수금 : 2213, 신용잔고 : 100806, 주식볼륨 : 849330
#
# 날짜 : 20200130, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 302230, 미수금 : 2524, 신용잔고 : 101070, 주식볼륨 : 854769
#
# 날짜 : 20200129, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 292199, 미수금 : 1821, 신용잔고 : 100926, 주식볼륨 : 863034
#
# 날짜 : 20200128, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 302212, 미수금 : 1692, 신용잔고 : 100197, 주식볼륨 : 865157
#
# 날짜 : 20200123, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 270329, 미수금 : 1981, 신용잔고 : 99996, 주식볼륨 : 879266
#
# 날짜 : 20200122, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 277625, 미수금 : 1973, 신용잔고 : 99505, 주식볼륨 : 885377
#
# 날짜 : 20200121, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 276795, 미수금 : 1898, 신용잔고 : 98925, 주식볼륨 : 882079
#
# 날짜 : 20200120, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 280321, 미수금 : 1994, 신용잔고 : 98792, 주식볼륨 : 887201
#
# 날짜 : 20200117, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 275459, 미수금 : 1939, 신용잔고 : 97740, 주식볼륨 : 891225
#
# 날짜 : 20200116, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 275710, 미수금 : 1897, 신용잔고 : 96955, 주식볼륨 : 891947
#
# 날짜 : 20200115, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 283605, 미수금 : 1876, 신용잔고 : 96445, 주식볼륨 : 889735
#
# 날짜 : 20200114, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 279788, 미수금 : 1849, 신용잔고 : 95432, 주식볼륨 : 894117
#
# 날짜 : 20200113, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 276410, 미수금 : 1974, 신용잔고 : 94596, 주식볼륨 : 891333
#
# 날짜 : 20200110, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 291714, 미수금 : 2201, 신용잔고 : 94934, 주식볼륨 : 886785
#
# 날짜 : 20200109, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 281540, 미수금 : 2063, 신용잔고 : 95323, 주식볼륨 : 881908
#
# 날짜 : 20200108, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 269139, 미수금 : 2202, 신용잔고 : 95316, 주식볼륨 : 877255
#
# 날짜 : 20200107, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 270384, 미수금 : 2006, 신용잔고 : 94792, 주식볼륨 : 879436
#
# 날짜 : 20200106, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 279480, 미수금 : 1817, 신용잔고 : 93769, 주식볼륨 : 878822
#
# 날짜 : 20200103, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 306665, 미수금 : 1563, 신용잔고 : 92316, 주식볼륨 : 872188
#
# 날짜 : 20200102, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 298599, 미수금 : 1670, 신용잔고 : 92072, 주식볼륨 : 878679
#
# 날짜 : 20191231, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 273384, 미수금 : 2126, 신용잔고 : 92133, 주식볼륨 : 877092
#
# 날짜 : 20191230, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 285195, 미수금 : 2132, 신용잔고 : 92181, 주식볼륨 : 876680
#
# 날짜 : 20191227, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 287137, 미수금 : 1861, 신용잔고 : 92338, 주식볼륨 : 878082
#
# 날짜 : 20191226, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 278230, 미수금 : 1770, 신용잔고 : 92694, 주식볼륨 : 864271
#
# 날짜 : 20191224, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 267400, 미수금 : 1675, 신용잔고 : 92886, 주식볼륨 : 858583
#
# 날짜 : 20191223, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 266275, 미수금 : 1806, 신용잔고 : 93050, 주식볼륨 : 858619
#
# 날짜 : 20191220, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 260195, 미수금 : 1738, 신용잔고 : 92971, 주식볼륨 : 858926
#
# 날짜 : 20191219, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 261736, 미수금 : 1649, 신용잔고 : 92415, 주식볼륨 : 855031
#
# 날짜 : 20191218, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 258140, 미수금 : 1639, 신용잔고 : 92203, 주식볼륨 : 853136
#
# 날짜 : 20191217, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 255937, 미수금 : 1551, 신용잔고 : 91890, 주식볼륨 : 846720
#
# 날짜 : 20191216, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244541, 미수금 : 1580, 신용잔고 : 92046, 주식볼륨 : 836194
#
# 날짜 : 20191213, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 249482, 미수금 : 1586, 신용잔고 : 92396, 주식볼륨 : 832430
#
# 날짜 : 20191212, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 243972, 미수금 : 1660, 신용잔고 : 92191, 주식볼륨 : 825547
#
# 날짜 : 20191211, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244462, 미수금 : 1634, 신용잔고 : 92192, 주식볼륨 : 820110
#
# 날짜 : 20191210, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241095, 미수금 : 1592, 신용잔고 : 91927, 주식볼륨 : 821003
#
# 날짜 : 20191209, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 235853, 미수금 : 1881, 신용잔고 : 92660, 주식볼륨 : 818864
#
# 날짜 : 20191206, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 237988, 미수금 : 1827, 신용잔고 : 93426, 주식볼륨 : 815439
#
# 날짜 : 20191205, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248128, 미수금 : 1752, 신용잔고 : 93472, 주식볼륨 : 811262
#
# 날짜 : 20191204, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 252576, 미수금 : 1860, 신용잔고 : 93573, 주식볼륨 : 810654
#
# 날짜 : 20191203, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248359, 미수금 : 1979, 신용잔고 : 94092, 주식볼륨 : 812633
#
# 날짜 : 20191202, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 262784, 미수금 : 1843, 신용잔고 : 94064, 주식볼륨 : 814050
#
# 날짜 : 20191129, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246711, 미수금 : 1731, 신용잔고 : 94158, 주식볼륨 : 814545
#
# 날짜 : 20191128, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 247399, 미수금 : 1681, 신용잔고 : 93722, 주식볼륨 : 816767
#
# 날짜 : 20191127, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248631, 미수금 : 1660, 신용잔고 : 93236, 주식볼륨 : 817679
#
# 날짜 : 20191126, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 249455, 미수금 : 1941, 신용잔고 : 93657, 주식볼륨 : 814425
#
# 날짜 : 20191125, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 252150, 미수금 : 2140, 신용잔고 : 94424, 주식볼륨 : 813789
#
# 날짜 : 20191122, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 264577, 미수금 : 2056, 신용잔고 : 95163, 주식볼륨 : 810745
#
# 날짜 : 20191121, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 261993, 미수금 : 1885, 신용잔고 : 95293, 주식볼륨 : 810276
#
# 날짜 : 20191120, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 259406, 미수금 : 1996, 신용잔고 : 95145, 주식볼륨 : 816984
#
# 날짜 : 20191119, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 251295, 미수금 : 1808, 신용잔고 : 94609, 주식볼륨 : 820788
#
# 날짜 : 20191118, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246071, 미수금 : 1881, 신용잔고 : 94936, 주식볼륨 : 819374
#
# 날짜 : 20191115, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248145, 미수금 : 1856, 신용잔고 : 95015, 주식볼륨 : 819695
#
# 날짜 : 20191114, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 261050, 미수금 : 1829, 신용잔고 : 94399, 주식볼륨 : 815627
#
# 날짜 : 20191113, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 252301, 미수금 : 1874, 신용잔고 : 94152, 주식볼륨 : 812102
#
# 날짜 : 20191112, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250699, 미수금 : 1744, 신용잔고 : 93597, 주식볼륨 : 814385
#
# 날짜 : 20191111, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 253272, 미수금 : 1932, 신용잔고 : 93354, 주식볼륨 : 812200
#
# 날짜 : 20191108, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 255469, 미수금 : 1952, 신용잔고 : 92623, 주식볼륨 : 811437
#
# 날짜 : 20191107, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 252719, 미수금 : 1839, 신용잔고 : 92075, 주식볼륨 : 814075
#
# 날짜 : 20191106, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250657, 미수금 : 1893, 신용잔고 : 91667, 주식볼륨 : 813703
#
# 날짜 : 20191105, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246093, 미수금 : 1836, 신용잔고 : 91303, 주식볼륨 : 809543
#
# 날짜 : 20191104, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 254581, 미수금 : 2017, 신용잔고 : 91066, 주식볼륨 : 807532
#
# 날짜 : 20191101, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 253931, 미수금 : 1881, 신용잔고 : 90881, 주식볼륨 : 802394
#
# 날짜 : 20191031, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250454, 미수금 : 1753, 신용잔고 : 90425, 주식볼륨 : 797714
#
# 날짜 : 20191030, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250824, 미수금 : 1850, 신용잔고 : 90015, 주식볼륨 : 799096
#
# 날짜 : 20191029, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 253078, 미수금 : 1914, 신용잔고 : 90329, 주식볼륨 : 801571
#
# 날짜 : 20191028, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 254112, 미수금 : 1912, 신용잔고 : 90176, 주식볼륨 : 803059
#
# 날짜 : 20191025, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250991, 미수금 : 1912, 신용잔고 : 90200, 주식볼륨 : 803468
#
# 날짜 : 20191024, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 251289, 미수금 : 2250, 신용잔고 : 89783, 주식볼륨 : 803807
#
# 날짜 : 20191023, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246216, 미수금 : 1818, 신용잔고 : 89902, 주식볼륨 : 800202
#
# 날짜 : 20191022, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248485, 미수금 : 1702, 신용잔고 : 89490, 주식볼륨 : 799558
#
# 날짜 : 20191021, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248412, 미수금 : 1681, 신용잔고 : 89028, 주식볼륨 : 797287
#
# 날짜 : 20191018, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241229, 미수금 : 1616, 신용잔고 : 88560, 주식볼륨 : 791758
#
# 날짜 : 20191017, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250809, 미수금 : 1651, 신용잔고 : 88406, 주식볼륨 : 794706
#
# 날짜 : 20191016, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248154, 미수금 : 1748, 신용잔고 : 87884, 주식볼륨 : 794719
#
# 날짜 : 20191015, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 266780, 미수금 : 1809, 신용잔고 : 87757, 주식볼륨 : 791728
#
# 날짜 : 20191014, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 255332, 미수금 : 1892, 신용잔고 : 87777, 주식볼륨 : 791182
#
# 날짜 : 20191011, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250087, 미수금 : 2105, 신용잔고 : 86968, 주식볼륨 : 789928
#
# 날짜 : 20191010, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244755, 미수금 : 2005, 신용잔고 : 87349, 주식볼륨 : 785002
#
# 날짜 : 20191008, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 239548, 미수금 : 1933, 신용잔고 : 88071, 주식볼륨 : 785357
#
# 날짜 : 20191007, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 243226, 미수금 : 1798, 신용잔고 : 88187, 주식볼륨 : 782335
#
# 날짜 : 20191004, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 276969, 미수금 : 1482, 신용잔고 : 87620, 주식볼륨 : 784141
#
# 날짜 : 20191002, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 292211, 미수금 : 1574, 신용잔고 : 87901, 주식볼륨 : 785794
#
# 날짜 : 20191001, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 263157, 미수금 : 1639, 신용잔고 : 88112, 주식볼륨 : 793840
#
# 날짜 : 20190930, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244568, 미수금 : 1896, 신용잔고 : 88002, 주식볼륨 : 793469
#
# 날짜 : 20190927, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 254027, 미수금 : 1921, 신용잔고 : 88979, 주식볼륨 : 791240
#
# 날짜 : 20190926, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 259199, 미수금 : 1453, 신용잔고 : 89282, 주식볼륨 : 0
#
# 날짜 : 20190925, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250367, 미수금 : 1488, 신용잔고 : 89330, 주식볼륨 : 790635
#
# 날짜 : 20190924, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 247099, 미수금 : 1487, 신용잔고 : 88978, 주식볼륨 : 792748
#
# 날짜 : 20190923, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 251127, 미수금 : 1589, 신용잔고 : 88933, 주식볼륨 : 793504
#
# 날짜 : 20190920, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 242164, 미수금 : 1548, 신용잔고 : 88445, 주식볼륨 : 794259
#
# 날짜 : 20190919, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 245035, 미수금 : 1626, 신용잔고 : 87699, 주식볼륨 : 792852
#
# 날짜 : 20190918, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244832, 미수금 : 1522, 신용잔고 : 86726, 주식볼륨 : 792381
#
# 날짜 : 20190917, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 249242, 미수금 : 1452, 신용잔고 : 86220, 주식볼륨 : 793162
#
# 날짜 : 20190916, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248114, 미수금 : 1653, 신용잔고 : 86356, 주식볼륨 : 794816
#
# 날짜 : 20190911, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 240550, 미수금 : 1681, 신용잔고 : 86479, 주식볼륨 : 793144
#
# 날짜 : 20190910, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 247563, 미수금 : 1545, 신용잔고 : 86282, 주식볼륨 : 791703
#
# 날짜 : 20190909, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241268, 미수금 : 1417, 신용잔고 : 85803, 주식볼륨 : 790924
#
# 날짜 : 20190906, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 237600, 미수금 : 1327, 신용잔고 : 85171, 주식볼륨 : 790058
#
# 날짜 : 20190905, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 239228, 미수금 : 1375, 신용잔고 : 84755, 주식볼륨 : 789412
#
# 날짜 : 20190904, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 237813, 미수금 : 1318, 신용잔고 : 84163, 주식볼륨 : 788075
#
# 날짜 : 20190903, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 235756, 미수금 : 1396, 신용잔고 : 83699, 주식볼륨 : 783753
#
# 날짜 : 20190902, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 251530, 미수금 : 1405, 신용잔고 : 84199, 주식볼륨 : 786236
#
# 날짜 : 20190830, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 232304, 미수금 : 1385, 신용잔고 : 83862, 주식볼륨 : 784395
#
# 날짜 : 20190829, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 240267, 미수금 : 1490, 신용잔고 : 83954, 주식볼륨 : 780311
#
# 날짜 : 20190828, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 237000, 미수금 : 1585, 신용잔고 : 84192, 주식볼륨 : 783378
#
# 날짜 : 20190827, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 245242, 미수금 : 1358, 신용잔고 : 84507, 주식볼륨 : 781508
#
# 날짜 : 20190826, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 242017, 미수금 : 1448, 신용잔고 : 84641, 주식볼륨 : 779134
#
# 날짜 : 20190823, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 237331, 미수금 : 1344, 신용잔고 : 83822, 주식볼륨 : 785830
#
# 날짜 : 20190822, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 239003, 미수금 : 1409, 신용잔고 : 83168, 주식볼륨 : 786363
#
# 날짜 : 20190821, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241387, 미수금 : 1473, 신용잔고 : 82973, 주식볼륨 : 788020
#
# 날짜 : 20190820, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244715, 미수금 : 1467, 신용잔고 : 83068, 주식볼륨 : 786868
#
# 날짜 : 20190819, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241076, 미수금 : 1534, 신용잔고 : 82917, 주식볼륨 : 783460
#
# 날짜 : 20190816, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 249913, 미수금 : 1512, 신용잔고 : 82448, 주식볼륨 : 783762
#
# 날짜 : 20190814, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 254148, 미수금 : 1493, 신용잔고 : 81831, 주식볼륨 : 785498
# 날짜 : 20190813, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 252187, 미수금 : 1775, 신용잔고 : 81005, 주식볼륨 : 783486
#
# 날짜 : 20190812, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 258775, 미수금 : 2357, 신용잔고 : 80309, 주식볼륨 : 785150
#
# 날짜 : 20190809, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 258438, 미수금 : 2355, 신용잔고 : 80130, 주식볼륨 : 783630
#
# 날짜 : 20190808, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 265692, 미수금 : 2451, 신용잔고 : 81821, 주식볼륨 : 782279
#
# 날짜 : 20190807, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 257775, 미수금 : 1903, 신용잔고 : 87105, 주식볼륨 : 780371
#
# 날짜 : 20190806, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 256406, 미수금 : 1269, 신용잔고 : 90164, 주식볼륨 : 779008
#
# 날짜 : 20190805, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246305, 미수금 : 1349, 신용잔고 : 91548, 주식볼륨 : 782806
#
# 날짜 : 20190802, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241558, 미수금 : 1358, 신용잔고 : 92425, 주식볼륨 : 790091
#
# 날짜 : 20190801, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 262508, 미수금 : 1420, 신용잔고 : 92886, 주식볼륨 : 793169
#
# 날짜 : 20190731, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241078, 미수금 : 1672, 신용잔고 : 94788, 주식볼륨 : 793464
#
# 날짜 : 20190730, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 242994, 미수금 : 1546, 신용잔고 : 96752, 주식볼륨 : 795857
#
# 날짜 : 20190729, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 245195, 미수금 : 1557, 신용잔고 : 98002, 주식볼륨 : 795191
#
# 날짜 : 20190726, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248585, 미수금 : 1526, 신용잔고 : 99292, 주식볼륨 : 802479
#
# 날짜 : 20190725, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244278, 미수금 : 1282, 신용잔고 : 100090, 주식볼륨 : 803018
#
# 날짜 : 20190724, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241131, 미수금 : 1206, 신용잔고 : 100110, 주식볼륨 : 804661
#
# 날짜 : 20190723, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 242129, 미수금 : 1240, 신용잔고 : 99735, 주식볼륨 : 807415
#
# 날짜 : 20190722, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241833, 미수금 : 1364, 신용잔고 : 100026, 주식볼륨 : 805981
#
# 날짜 : 20190719, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244479, 미수금 : 1355, 신용잔고 : 100136, 주식볼륨 : 806933
#
# 날짜 : 20190718, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244744, 미수금 : 1386, 신용잔고 : 100117, 주식볼륨 : 801783
#
# 날짜 : 20190717, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 239065, 미수금 : 1427, 신용잔고 : 99945, 주식볼륨 : 802964
#
# 날짜 : 20190716, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 238733, 미수금 : 1157, 신용잔고 : 99569, 주식볼륨 : 805790
#
# 날짜 : 20190715, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 249210, 미수금 : 1217, 신용잔고 : 99076, 주식볼륨 : 804103
#
# 날짜 : 20190712, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 242357, 미수금 : 1500, 신용잔고 : 98953, 주식볼륨 : 803167
#
# 날짜 : 20190711, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241386, 미수금 : 1672, 신용잔고 : 99228, 주식볼륨 : 802245
#
# 날짜 : 20190710, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 243732, 미수금 : 1601, 신용잔고 : 101042, 주식볼륨 : 799399
#
# 날짜 : 20190709, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 245999, 미수금 : 1396, 신용잔고 : 101756, 주식볼륨 : 800163
#
# 날짜 : 20190708, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 249578, 미수금 : 1497, 신용잔고 : 101966, 주식볼륨 : 801271
#
# 날짜 : 20190705, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244098, 미수금 : 1504, 신용잔고 : 102188, 주식볼륨 : 806255
#
# 날짜 : 20190704, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246573, 미수금 : 1445, 신용잔고 : 101771, 주식볼륨 : 806966
#
# 날짜 : 20190703, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 245303, 미수금 : 1652, 신용잔고 : 101556, 주식볼륨 : 806478
#
# 날짜 : 20190702, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 249327, 미수금 : 1431, 신용잔고 : 102296, 주식볼륨 : 810117
#
# 날짜 : 20190701, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 274384, 미수금 : 1489, 신용잔고 : 103632, 주식볼륨 : 811674
#
# 날짜 : 20190628, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 247103, 미수금 : 1566, 신용잔고 : 104701, 주식볼륨 : 815366
#
# 날짜 : 20190627, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250548, 미수금 : 1651, 신용잔고 : 105094, 주식볼륨 : 815027
#
# 날짜 : 20190626, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 251786, 미수금 : 1306, 신용잔고 : 105072, 주식볼륨 : 812440
#
# 날짜 : 20190625, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246315, 미수금 : 1184, 신용잔고 : 105004, 주식볼륨 : 810591
#
# 날짜 : 20190624, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 250512, 미수금 : 1248, 신용잔고 : 104515, 주식볼륨 : 812341
#
# 날짜 : 20190621, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 243690, 미수금 : 1415, 신용잔고 : 104463, 주식볼륨 : 810557
#
# 날짜 : 20190620, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 244838, 미수금 : 1430, 신용잔고 : 104991, 주식볼륨 : 809562
#
# 날짜 : 20190619, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 238732, 미수금 : 1409, 신용잔고 : 105092, 주식볼륨 : 809818
#
# 날짜 : 20190618, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 239473, 미수금 : 1353, 신용잔고 : 105024, 주식볼륨 : 804835
#
# 날짜 : 20190617, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246938, 미수금 : 1237, 신용잔고 : 104351, 주식볼륨 : 801581
#
# 날짜 : 20190614, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 241401, 미수금 : 1183, 신용잔고 : 103730, 주식볼륨 : 802902
#
# 날짜 : 20190613, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 248130, 미수금 : 1082, 신용잔고 : 103000, 주식볼륨 : 803870
#
# 날짜 : 20190612, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 246108, 미수금 : 1137, 신용잔고 : 102626, 주식볼륨 : 806966
#
# 날짜 : 20190611, 지수 : 0, 등락율 : 0, 거래량 : 0, 예탁금 : 243837, 미수금 : 1055, 신용잔고 : 102278, 주식볼륨 : 811345
#
# # END
