# %%
# !pip install PyGithub requests
# !pip install gitpython
# Out:
# ^C

# %%
import requests
import base64
from github import Github
from pprint import pprint
import datetime, time# for sleep

# github username
username = "stockpy"
password = "Dlfdltka123!"
# url to request
url = f"https://api.github.com/users/{username}"
# make the request and return the json
user_data = requests.get(url).json()
# pretty print JSON data
pprint(user_data)
print("############### 1")
time.sleep(1)
# pygithub object
g = Github()
# get that user by username
user = g.get_user(username)

for repo in user.get_repos():
    print(repo)
print("############### 2")
time.sleep(1)
def print_repo(repo):
    # repository full name
    print("Full name:", repo.full_name)
    # repository description
    print("Description:", repo.description)
    # the date of when the repo was created
    print("Date created:", repo.created_at)
    # the date of the last git push
    print("Date of last push:", repo.pushed_at)
    # home website (if available)
    print("Home Page:", repo.homepage)
    # programming language
    print("Language:", repo.language)
    # number of forks
    print("Number of forks:", repo.forks)
    # number of stars
    print("Number of stars:", repo.stargazers_count)
    print("-"*50)
    # repository content (files & directories)
    print("Contents:")
    for content in repo.get_contents(""):
        print(content)
    try:
        # repo license
        print("License:", base64.b64decode(repo.get_license().content.encode()).decode())
    except:
        pass
print("############### 3")
time.sleep(1)
print_repo(repo)
print("############### 4")
time.sleep(1)
# iterate over all public repositories
for repo in user.get_repos():
    print_repo(repo)
    print("="*100)
print("############### 5")
time.sleep(1)
# authenticate to github
# g = Github(username, password)
# get the authenticated user
# user = g.get_user()
for repo in user.get_repos():
    print_repo(repo)

print("############### 6")
time.sleep(1)
# create a file and commit n push
repo.create_file("Stock_202011125.html", "commit message", "Stock_202011125.html-- TEST")
print("############### 7")
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/64298149?v=4',
#  'bio': None,
#  'blog': '',
#  'company': None,
#  'created_at': '2020-04-25T04:39:49Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/stockpy/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/stockpy/followers',
#  'following': 0,
#  'following_url': 'https://api.github.com/users/stockpy/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/stockpy/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/stockpy',
#  'id': 64298149,
#  'location': None,
#  'login': 'stockpy',
#  'name': None,
#  'node_id': 'MDQ6VXNlcjY0Mjk4MTQ5',
#  'organizations_url': 'https://api.github.com/users/stockpy/orgs',
#  'public_gists': 1,
#  'public_repos': 3,
#  'received_events_url': 'https://api.github.com/users/stockpy/received_events',
#  'repos_url': 'https://api.github.com/users/stockpy/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/stockpy/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/stockpy/subscriptions',
#  'twitter_username': None,
#  'type': 'User',
#  'updated_at': '2021-04-25T12:17:10Z',
#  'url': 'https://api.github.com/users/stockpy'}
# ############### 1
# Repository(full_name="stockpy/stockpy")
# Repository(full_name="stockpy/stockpy.github.io")
# Repository(full_name="stockpy/Work")
# ############### 2
# ############### 3
# Full name: stockpy/Work
# Description: None
# Date created: 2021-04-16 06:39:44
# Date of last push: 2021-04-16 06:39:44
# Home Page: None
# Language: None
# Number of forks: 0
# Number of stars: 0
# --------------------------------------------------
# Contents:
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# <ipython-input-2-9b2de466232b> in <module>
#      54 print("############### 3")
#      55 time.sleep(1)
# ---> 56 print_repo(repo)
#      57 print("############### 4")
#      58 time.sleep(1)
#
# <ipython-input-2-9b2de466232b> in print_repo(repo)
#      45     # repository content (files & directories)
#      46     print("Contents:")
# ---> 47     for content in repo.get_contents(""):
#      48         print(content)
#      49     try:
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Repository.py in get_contents(self, path, ref)
#    1753             "GET",
#    1754             self.url + "/contents/" + urllib.parse.quote(path),
# -> 1755             parameters=url_parameters,
#    1756         )
#    1757
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# GithubException: 404 {"message": "This repository is empty.", "documentation_url": "https://docs.github.com/v3/repos/contents/#get-contents"}

# %%
import base64
from github import Github
from github import InputGitTreeElement
import datetime, time# for sleep

github_user = "stockpy"
github_password = "Dlfdltka123!"
g = Github(github_user,github_password)

user = g.get_user(github_user)

for repo in user.get_repos():
    repo = repo
    
file_list = [
    'D:\\Python\\Log\\NB_20200906.html'
]

file_names = [
    'NB_20200906.html'
]
# NB file 의 경우 에러 발생 : UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 287737: illegal multibyte sequence

_Name = datetime.datetime.today().strftime("_%Y%m%d")
    
commit_message = 'python update 2'
master_ref = repo.get_git_ref('heads/master')
master_sha = master_ref.object.sha
base_tree = repo.get_git_tree(master_sha)
element_list = list()
for i, entry in enumerate(file_list):
    with open(entry) as input_file:
        print(entry)
        data = input_file.read()
    if entry.endswith('.png') :
        data = base64.b64encode(data)
    element = InputGitTreeElement(file_names[i], '100644', 'blob', data)
    element_list.append(element)
tree = repo.create_git_tree(element_list, base_tree)
parent = repo.get_git_commit(master_sha)
commit = repo.create_git_commit(commit_message, tree, [parent])
master_ref.edit(commit.sha)
# Out:
# D:\Python\Log\NB_20200906.html
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-e0d7d2f73c0c> in <module>
#      32     with open(entry) as input_file:
#      33         print(entry)
# ---> 34         data = input_file.read()
#      35     if entry.endswith('.png') :
#      36         data = base64.b64encode(data)
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 287737: illegal multibyte sequence

# %%
import requests
import base64

username = 'stockpy'
token = 'e283d417face50d97a0cfdb81095a36d60683385'

login = requests.get('https://api.github.com/search/repositories?q=github+api', auth=(username,token))

print(login)

headers = {'Authorization': 'token ' + token}

login = requests.get('https://api.github.com/user', headers=headers)
print(login.json())

# delete REPO
repo = 'some_repo' # Delete this repo

headers = {'Authorization': 'token ' + token}

login = requests.delete('https://api.github.com/' + 'repos/' + username + '/' + repo, headers=headers)

# create REPO
repo = 'some_repo'
description = 'Created with api'

payload = {'name': repo, 'description': description, 'auto_init': 'true'}

login = requests.post('http://stockpy.github.io/' + 'user/repos', auth=(user,token), data=json.dumps(payload))
# Out:
# <Response [200]>
# {'login': 'stockpy', 'id': 64298149, 'node_id': 'MDQ6VXNlcjY0Mjk4MTQ5', 'avatar_url': 'https://avatars.githubusercontent.com/u/64298149?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/stockpy', 'html_url': 'https://github.com/stockpy', 'followers_url': 'https://api.github.com/users/stockpy/followers', 'following_url': 'https://api.github.com/users/stockpy/following{/other_user}', 'gists_url': 'https://api.github.com/users/stockpy/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/stockpy/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/stockpy/subscriptions', 'organizations_url': 'https://api.github.com/users/stockpy/orgs', 'repos_url': 'https://api.github.com/users/stockpy/repos', 'events_url': 'https://api.github.com/users/stockpy/events{/privacy}', 'received_events_url': 'https://api.github.com/users/stockpy/received_events', 'type': 'User', 'site_admin': False, 'name': None, 'company': None, 'blog': '', 'location': None, 'email': None, 'hireable': None, 'bio': None, 'twitter_username': None, 'public_repos': 1, 'public_gists': 1, 'followers': 0, 'following': 0, 'created_at': '2020-04-25T04:39:49Z', 'updated_at': '2021-02-25T12:43:25Z'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b2f45d5c09b1> in <module>
#      27 payload = {'name': repo, 'description': description, 'auto_init': 'true'}
#      28
# ---> 29 login = requests.post('http://stockpy.github.io/' + 'user/repos', auth=(user,token), data=json.dumps(payload))
#
# NameError: name 'json' is not defined

# %%
# 실제 되던 GITHUB
import base64
from github import Github
from github import InputGitTreeElement
import datetime, time# for sleep

def __Github_Upload() :
    
    Github_user = "stockpy"
    Github_password = "Dlfdltka123!"
    
    g = Github(Github_user,Github_password)

    user = g.get_user(Github_user)

    for repo in user.get_repos():
        repo = repo
        print(repo)

    _Name = datetime.datetime.today().strftime("_%Y%m%d")
    
    file1 = "D:\\Python\\Log\\Money_Flow.html"

    # NB file 의 경우 에러 발생 : UnicodeDecodeError: 'cp949' codec can't decode byte 0xec in position 287737: illegal multibyte sequence
    file_list = [file1]
    file_names = ["Money_Flow.html"]
    commit_message = 'Stock Python'+_Name

    master_ref = repo.get_git_ref('heads/master')
    master_sha = master_ref.object.sha
    base_tree = repo.get_git_tree(master_sha)
    
    print(base_tree)
    
    element_list = list()
    for i, entry in enumerate(file_list):
        with open(entry) as input_file:
            print(input_file)
            data = input_file.read()
        if entry.endswith('.png'):
            data = base64.b64encode(data)
        element = InputGitTreeElement(file_names[i], '100644', 'blob', data)
        element_list.append(element)

    print(element_list)
    
    tree = repo.create_git_tree(element_list, base_tree)
    parent = repo.get_git_commit(master_sha)
    commit = repo.create_git_commit(commit_message, tree, [parent])
    master_ref.edit(commit.sha)
    
if __name__ == '__main__' :
    __Github_Upload()
# Out:
# Repository(full_name="stockpy/stockpy")
# Repository(full_name="stockpy/stockpy.github.io")
# Repository(full_name="stockpy/Work")
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# <ipython-input-2-ef3fc3e10da4> in <module>
#      51
#      52 if __name__ == '__main__' :
# ---> 53     __Github_Upload()
#
# <ipython-input-2-ef3fc3e10da4> in __Github_Upload()
#      27     commit_message = 'Stock Python'+_Name
#      28
# ---> 29     master_ref = repo.get_git_ref('heads/master')
#      30     master_sha = master_ref.object.sha
#      31     base_tree = repo.get_git_tree(master_sha)
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Repository.py in get_git_ref(self, ref)
#    2287         assert isinstance(ref, str), ref
#    2288         headers, data = self._requester.requestJsonAndCheck(
# -> 2289             "GET", self.url + prefix + ref
#    2290         )
#    2291         return github.GitRef.GitRef(self._requester, headers, data, completed=True)
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# GithubException: 409 {"message": "Git Repository is empty.", "documentation_url": "https://docs.github.com/enterprise/2.18/user/rest/reference/git#get-a-reference"}

# %%
import requests
from pprint import pprint
from github import Github

# github username
username = "stockpy"
# url to request
url = f"https://api.github.com/users/{username}"
# make the request and return the json
user_data = requests.get(url).json()
# pretty print JSON data
pprint(user_data)

print("################")
# pygithub object
g = Github()
# get that user by username
user = g.get_user(username)

for repo in user.get_repos():
    print(repo)

print("################")
    
username = "stockpy"
password = "Dlfdltka123!"

# authenticate to github
g = Github(username, password)
# get the authenticated user
user = g.get_user()
for repo in user.get_repos():
    print_repo(repo)
    
print("################")

# searching for my repository
repo = g.search_repositories("pythoncode tutorials")[0]

# create a file and commit n push
repo.create_file("test.txt", "commit message", "content of the file")

# delete that created file
contents = repo.get_contents("test.txt")
repo.delete_file(contents.path, "remove test.txt", contents.sha)
# Out:
# {'avatar_url': 'https://avatars.githubusercontent.com/u/64298149?v=4',
#  'bio': None,
#  'blog': '',
#  'company': None,
#  'created_at': '2020-04-25T04:39:49Z',
#  'email': None,
#  'events_url': 'https://api.github.com/users/stockpy/events{/privacy}',
#  'followers': 0,
#  'followers_url': 'https://api.github.com/users/stockpy/followers',
#  'following': 0,
#  'following_url': 'https://api.github.com/users/stockpy/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/stockpy/gists{/gist_id}',
#  'gravatar_id': '',
#  'hireable': None,
#  'html_url': 'https://github.com/stockpy',
#  'id': 64298149,
#  'location': None,
#  'login': 'stockpy',
#  'name': None,
#  'node_id': 'MDQ6VXNlcjY0Mjk4MTQ5',
#  'organizations_url': 'https://api.github.com/users/stockpy/orgs',
#  'public_gists': 1,
#  'public_repos': 3,
#  'received_events_url': 'https://api.github.com/users/stockpy/received_events',
#  'repos_url': 'https://api.github.com/users/stockpy/repos',
#  'site_admin': False,
#  'starred_url': 'https://api.github.com/users/stockpy/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/stockpy/subscriptions',
#  'twitter_username': None,
#  'type': 'User',
#  'updated_at': '2021-04-25T12:17:10Z',
#  'url': 'https://api.github.com/users/stockpy'}
# ################
# Repository(full_name="stockpy/stockpy")
# Repository(full_name="stockpy/stockpy.github.io")
# Repository(full_name="stockpy/Work")
# ################
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# <ipython-input-4-995b4dbbe9a9> in <module>
#      30 # get the authenticated user
#      31 user = g.get_user()
# ---> 32 for repo in user.get_repos():
#      33     print_repo(repo)
#      34
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\PaginatedList.py in __iter__(self)
#      57             yield element
#      58         while self._couldGrow():
# ---> 59             newElements = self._grow()
#      60             for element in newElements:
#      61                 yield element
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\PaginatedList.py in _grow(self)
#      69
#      70     def _grow(self):
# ---> 71         newElements = self._fetchNextPage()
#      72         self.__elements += newElements
#      73         return newElements
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\PaginatedList.py in _fetchNextPage(self)
#     202     def _fetchNextPage(self):
#     203         headers, data = self.__requester.requestJsonAndCheck(
# --> 204             "GET", self.__nextUrl, parameters=self.__nextParams, headers=self.__headers
#     205         )
#     206         data = data if data else []
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# GithubException: 401 {"message": "Requires authentication", "documentation_url": "https://docs.github.com/rest/reference/repos#list-repositories-for-the-authenticated-user"}

# %%
from github import Github
g = Github("stockpy", "Dlfdltka123!")

repo = g.get_user().get_repo(GITHUB_REPO)
all_files = []
contents = repo.get_contents("")
while contents:
    file_content = contents.pop(0)
    if file_content.type == "dir":
        contents.extend(repo.get_contents(file_content.path))
    else:
        file = file_content
        all_files.append(str(file).replace('ContentFile(path="','').replace('")',''))

with open('/tmp/file.txt', 'r') as file:
    content = file.read()

# Upload to github
git_prefix = 'folder1/'
git_file = git_prefix + 'file.txt'
if git_file in all_files:
    contents = repo.get_contents(git_file)
    repo.update_file(contents.path, "committing files", content, contents.sha, branch="master")
    print(git_file + ' UPDATED')
else:
    repo.create_file(git_file, "committing files", content, branch="master")
    print(git_file + ' CREATED')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-97301376f0d4> in <module>
#       2 g = Github("stockpy", "Dlfdltka123!")
#       3
# ----> 4 repo = g.get_user().get_repo(GITHUB_REPO)
#       5 all_files = []
#       6 contents = repo.get_contents("")
#
# NameError: name 'GITHUB_REPO' is not defined

# %%
import requests
import json
r = requests.get('https://api.github.com/repos/stockpy/stockpy.github.io/contents')
# https://api.github.com/repos/lassana/continuous-audiorecorder/contents/

for x in r :
    print(x)
    print("")
    
if(r.ok):
    repoItem = json.loads(r.text or r.content)
    print("Django repository created: " + repoItem['created_at'])
# Out:
# b'[{"name":".DS_Store","path":".DS_Store","sha":"3018dcc06a44a58ac1c028b7b83a1cedbb0ebf37","size":6148,"url":"https://api.github.c'
#
# b'om/repos/stockpy/stockpy.github.io/contents/.DS_Store?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/'
#
# b'master/.DS_Store","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/3018dcc06a44a58ac1c028b7b83a1cedbb'
#
# b'0ebf37","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/.DS_Store","type":"file","_links":{"s'
#
# b'elf":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/.DS_Store?ref=master","git":"https://api.github.com/repos/'
#
# b'stockpy/stockpy.github.io/git/blobs/3018dcc06a44a58ac1c028b7b83a1cedbb0ebf37","html":"https://github.com/stockpy/stockpy.github.'
#
# b'io/blob/master/.DS_Store"}},{"name":".gitignore","path":".gitignore","sha":"695f96069a985a285c6746192958320325f6f40b","size":130'
#
# b',"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/.gitignore?ref=master","html_url":"https://github.com/st'
#
# b'ockpy/stockpy.github.io/blob/master/.gitignore","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/695f'
#
# b'96069a985a285c6746192958320325f6f40b","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/.gitign'
#
# b'ore","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/.gitignore?ref=master","git'
#
# b'":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/695f96069a985a285c6746192958320325f6f40b","html":"https://gi'
#
# b'thub.com/stockpy/stockpy.github.io/blob/master/.gitignore"}},{"name":".ipynb_checkpoints","path":".ipynb_checkpoints","sha":"d1b'
#
# b'6145148a26252805e70797cdca3c226e8d607","size":0,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/.ipynb_ch'
#
# b'eckpoints?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/tree/master/.ipynb_checkpoints","git_url":"https:'
#
# b'//api.github.com/repos/stockpy/stockpy.github.io/git/trees/d1b6145148a26252805e70797cdca3c226e8d607","download_url":null,"type":'
#
# b'"dir","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/.ipynb_checkpoints?ref=master","git":"ht'
#
# b'tps://api.github.com/repos/stockpy/stockpy.github.io/git/trees/d1b6145148a26252805e70797cdca3c226e8d607","html":"https://github.'
#
# b'com/stockpy/stockpy.github.io/tree/master/.ipynb_checkpoints"}},{"name":"00. Stock_Main_Pandas.ipynb","path":"00. Stock_Main_Pan'
#
# b'das.ipynb","sha":"043e02fda2328c48b97ed537eb880aaf4943d165","size":129762,"url":"https://api.github.com/repos/stockpy/stockpy.gi'
#
# b'thub.io/contents/00.%20Stock_Main_Pandas.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/'
#
# b'00.%20Stock_Main_Pandas.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/043e02fda2328c48b97ed'
#
# b'537eb880aaf4943d165","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/00.%20Stock_Main_Pandas.'
#
# b'ipynb","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/00.%20Stock_Main_Pandas.i'
#
# b'pynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/043e02fda2328c48b97ed537eb880aaf4943d16'
#
# b'5","html":"https://github.com/stockpy/stockpy.github.io/blob/master/00.%20Stock_Main_Pandas.ipynb"}},{"name":"00. TEST_Python.ip'
#
# b'ynb","path":"00. TEST_Python.ipynb","sha":"7182b9cb65d6628f18a489c9033692c5d21c42e3","size":30198,"url":"https://api.github.com/'
#
# b'repos/stockpy/stockpy.github.io/contents/00.%20TEST_Python.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.gith'
#
# b'ub.io/blob/master/00.%20TEST_Python.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/7182b9cb6'
#
# b'5d6628f18a489c9033692c5d21c42e3","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/00.%20TEST_P'
#
# b'ython.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/00.%20TEST_Python.i'
#
# b'pynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/7182b9cb65d6628f18a489c9033692c5d21c42e'
#
# b'3","html":"https://github.com/stockpy/stockpy.github.io/blob/master/00.%20TEST_Python.ipynb"}},{"name":"20200831.html","path":"2'
#
# b'0200831.html","sha":"8e01c2cc7173daa4984e80e559f07897db41e4b6","size":640920,"url":"https://api.github.com/repos/stockpy/stockpy'
#
# b'.github.io/contents/20200831.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/20200831.html'
#
# b'","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/8e01c2cc7173daa4984e80e559f07897db41e4b6","downloa'
#
# b'd_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/20200831.html","type":"file","_links":{"self":"https:'
#
# b'//api.github.com/repos/stockpy/stockpy.github.io/contents/20200831.html?ref=master","git":"https://api.github.com/repos/stockpy/'
#
# b'stockpy.github.io/git/blobs/8e01c2cc7173daa4984e80e559f07897db41e4b6","html":"https://github.com/stockpy/stockpy.github.io/blob/'
#
# b'master/20200831.html"}},{"name":"20210425_tabulate.html","path":"20210425_tabulate.html","sha":"d4fa4e2567e9852c2bd99dcf7fb38df8'
#
# b'7161ec9c","size":9157,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/20210425_tabulate.html?ref=master",'
#
# b'"html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/20210425_tabulate.html","git_url":"https://api.github.com/r'
#
# b'epos/stockpy/stockpy.github.io/git/blobs/d4fa4e2567e9852c2bd99dcf7fb38df87161ec9c","download_url":"https://raw.githubusercontent'
#
# b'.com/stockpy/stockpy.github.io/master/20210425_tabulate.html","type":"file","_links":{"self":"https://api.github.com/repos/stock'
#
# b'py/stockpy.github.io/contents/20210425_tabulate.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/g'
#
# b'it/blobs/d4fa4e2567e9852c2bd99dcf7fb38df87161ec9c","html":"https://github.com/stockpy/stockpy.github.io/blob/master/20210425_tab'
#
# b'ulate.html"}},{"name":"BitToday.html","path":"BitToday.html","sha":"0d12b7e84487d5227bf5855e5418cb82d8a394ab","size":2520037,"ur'
#
# b'l":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/BitToday.html?ref=master","html_url":"https://github.com/sto'
#
# b'ckpy/stockpy.github.io/blob/master/BitToday.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/0d'
#
# b'12b7e84487d5227bf5855e5418cb82d8a394ab","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/BitTo'
#
# b'day.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/BitToday.html?ref=mast'
#
# b'er","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/0d12b7e84487d5227bf5855e5418cb82d8a394ab","html":"ht'
#
# b'tps://github.com/stockpy/stockpy.github.io/blob/master/BitToday.html"}},{"name":"Bitpython.txt","path":"Bitpython.txt","sha":"ef'
#
# b'bf5082b89aebe472e988eb6c993d7dec4b2395","size":46094,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Bitp'
#
# b'ython.txt?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Bitpython.txt","git_url":"https://api'
#
# b'.github.com/repos/stockpy/stockpy.github.io/git/blobs/efbf5082b89aebe472e988eb6c993d7dec4b2395","download_url":"https://raw.gith'
#
# b'ubusercontent.com/stockpy/stockpy.github.io/master/Bitpython.txt","type":"file","_links":{"self":"https://api.github.com/repos/s'
#
# b'tockpy/stockpy.github.io/contents/Bitpython.txt?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/bl'
#
# b'obs/efbf5082b89aebe472e988eb6c993d7dec4b2395","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Bitpython.txt"}},'
#
# b'{"name":"CL_Action_Table.txt","path":"CL_Action_Table.txt","sha":"178a8850b1d7b04dd77cd74023c7f51ee24a97c6","size":38106,"url":"'
#
# b'https://api.github.com/repos/stockpy/stockpy.github.io/contents/CL_Action_Table.txt?ref=master","html_url":"https://github.com/s'
#
# b'tockpy/stockpy.github.io/blob/master/CL_Action_Table.txt","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/'
#
# b'blobs/178a8850b1d7b04dd77cd74023c7f51ee24a97c6","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/mast'
#
# b'er/CL_Action_Table.txt","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/CL_Actio'
#
# b'n_Table.txt?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/178a8850b1d7b04dd77cd74023c7f51e'
#
# b'e24a97c6","html":"https://github.com/stockpy/stockpy.github.io/blob/master/CL_Action_Table.txt"}},{"name":"CORPCODE.xml","path":'
#
# b'"CORPCODE.xml","sha":"07f81648e430ca264445ddaee9ee79a292b376ca","size":16034890,"url":"https://api.github.com/repos/stockpy/stoc'
#
# b'kpy.github.io/contents/CORPCODE.xml?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/CORPCODE.xm'
#
# b'l","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/07f81648e430ca264445ddaee9ee79a292b376ca","downlo'
#
# b'ad_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/CORPCODE.xml","type":"file","_links":{"self":"https:'
#
# b'//api.github.com/repos/stockpy/stockpy.github.io/contents/CORPCODE.xml?ref=master","git":"https://api.github.com/repos/stockpy/s'
#
# b'tockpy.github.io/git/blobs/07f81648e430ca264445ddaee9ee79a292b376ca","html":"https://github.com/stockpy/stockpy.github.io/blob/m'
#
# b'aster/CORPCODE.xml"}},{"name":"Check_Human_Index.ipynb","path":"Check_Human_Index.ipynb","sha":"315d97ea348d2802d8e02eb78763a1fc'
#
# b'1b1d007a","size":113605,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Check_Human_Index.ipynb?ref=maste'
#
# b'r","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Check_Human_Index.ipynb","git_url":"https://api.github.c'
#
# b'om/repos/stockpy/stockpy.github.io/git/blobs/315d97ea348d2802d8e02eb78763a1fc1b1d007a","download_url":"https://raw.githubusercon'
#
# b'tent.com/stockpy/stockpy.github.io/master/Check_Human_Index.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/'
#
# b'stockpy/stockpy.github.io/contents/Check_Human_Index.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.githu'
#
# b'b.io/git/blobs/315d97ea348d2802d8e02eb78763a1fc1b1d007a","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Check_'
#
# b'Human_Index.ipynb"}},{"name":"Echart_Test.html","path":"Echart_Test.html","sha":"e69de29bb2d1d6434b8b29ae775ad8c2e48c5391","size'
#
# b'":0,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Echart_Test.html?ref=master","html_url":"https://gith'
#
# b'ub.com/stockpy/stockpy.github.io/blob/master/Echart_Test.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io'
#
# b'/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io'
#
# b'/master/Echart_Test.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Echart'
#
# b'_Test.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e'
#
# b'48c5391","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Echart_Test.html"}},{"name":"Echart_Test_1.html","path'
#
# b'":"Echart_Test_1.html","sha":"ff52f6e26037c6da89d7625932cea5ccc051c11c","size":867,"url":"https://api.github.com/repos/stockpy/s'
#
# b'tockpy.github.io/contents/Echart_Test_1.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Ec'
#
# b'hart_Test_1.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/ff52f6e26037c6da89d7625932cea5ccc0'
#
# b'51c11c","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Echart_Test_1.html","type":"file","_l'
#
# b'inks":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Echart_Test_1.html?ref=master","git":"https://api'
#
# b'.github.com/repos/stockpy/stockpy.github.io/git/blobs/ff52f6e26037c6da89d7625932cea5ccc051c11c","html":"https://github.com/stock'
#
# b'py/stockpy.github.io/blob/master/Echart_Test_1.html"}},{"name":"Echart_Test_2.html","path":"Echart_Test_2.html","sha":"de6270056'
#
# b'692710971025acf84783e4f28cbd4f6","size":148,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Echart_Test_2'
#
# b'.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Echart_Test_2.html","git_url":"https://ap'
#
# b'i.github.com/repos/stockpy/stockpy.github.io/git/blobs/de6270056692710971025acf84783e4f28cbd4f6","download_url":"https://raw.git'
#
# b'hubusercontent.com/stockpy/stockpy.github.io/master/Echart_Test_2.html","type":"file","_links":{"self":"https://api.github.com/r'
#
# b'epos/stockpy/stockpy.github.io/contents/Echart_Test_2.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.githu'
#
# b'b.io/git/blobs/de6270056692710971025acf84783e4f28cbd4f6","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Echart'
#
# b'_Test_2.html"}},{"name":"Github_API.ipynb","path":"Github_API.ipynb","sha":"6be61eb063b40b3fbd19e53b4fa28d40c6a46657","size":430'
#
# b'58,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Github_API.ipynb?ref=master","html_url":"https://githu'
#
# b'b.com/stockpy/stockpy.github.io/blob/master/Github_API.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/'
#
# b'git/blobs/6be61eb063b40b3fbd19e53b4fa28d40c6a46657","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/'
#
# b'master/Github_API.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Github_'
#
# b'API.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/6be61eb063b40b3fbd19e53b4fa28d40c6'
#
# b'a46657","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Github_API.ipynb"}},{"name":"Google_API.ipynb","path":"'
#
# b'Google_API.ipynb","sha":"879e5e2a153c790abe477b369e3bf80543e6351b","size":4984,"url":"https://api.github.com/repos/stockpy/stock'
#
# b'py.github.io/contents/Google_API.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Google_A'
#
# b'PI.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/879e5e2a153c790abe477b369e3bf80543e6351b",'
#
# b'"download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Google_API.ipynb","type":"file","_links":{"se'
#
# b'lf":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Google_API.ipynb?ref=master","git":"https://api.github.com/'
#
# b'repos/stockpy/stockpy.github.io/git/blobs/879e5e2a153c790abe477b369e3bf80543e6351b","html":"https://github.com/stockpy/stockpy.g'
#
# b'ithub.io/blob/master/Google_API.ipynb"}},{"name":"Hot_Spot.html","path":"Hot_Spot.html","sha":"d670be9bd4644e3a780178d72546f3019'
#
# b'48fdf66","size":102289,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Hot_Spot.html?ref=master","html_ur'
#
# b'l":"https://github.com/stockpy/stockpy.github.io/blob/master/Hot_Spot.html","git_url":"https://api.github.com/repos/stockpy/stoc'
#
# b'kpy.github.io/git/blobs/d670be9bd4644e3a780178d72546f301948fdf66","download_url":"https://raw.githubusercontent.com/stockpy/stoc'
#
# b'kpy.github.io/master/Hot_Spot.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/conte'
#
# b'nts/Hot_Spot.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/d670be9bd4644e3a780178d725'
#
# b'46f301948fdf66","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Hot_Spot.html"}},{"name":"KINDEX\xea\xb3\xa8\xeb\x93\x9c\xec\x84\xa0\xeb\xac\xbc\xeb\xa0\x88'
#
# b'\xeb\xb2\x84.html","path":"KINDEX\xea\xb3\xa8\xeb\x93\x9c\xec\x84\xa0\xeb\xac\xbc\xeb\xa0\x88\xeb\xb2\x84.html","sha":"3881d500f9be7082fbd7fe1e63d53603a14b6ad5","size":41891,"url":"https://ap'
#
# b'i.github.com/repos/stockpy/stockpy.github.io/contents/KINDEX%EA%B3%A8%EB%93%9C%EC%84%A0%EB%AC%BC%EB%A0%88%EB%B2%84.html?ref=mast'
#
# b'er","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/KINDEX%EA%B3%A8%EB%93%9C%EC%84%A0%EB%AC%BC%EB%A0%88%EB%'
#
# b'B2%84.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/3881d500f9be7082fbd7fe1e63d53603a14b6ad5'
#
# b'","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/KINDEX%EA%B3%A8%EB%93%9C%EC%84%A0%EB%AC%BC%'
#
# b'EB%A0%88%EB%B2%84.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/KINDEX%E'
#
# b'A%B3%A8%EB%93%9C%EC%84%A0%EB%AC%BC%EB%A0%88%EB%B2%84.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github'
#
# b'.io/git/blobs/3881d500f9be7082fbd7fe1e63d53603a14b6ad5","html":"https://github.com/stockpy/stockpy.github.io/blob/master/KINDEX%'
#
# b'EA%B3%A8%EB%93%9C%EC%84%A0%EB%AC%BC%EB%A0%88%EB%B2%84.html"}},{"name":"KODEX\xea\xb5\xac\xeb\xa6\xac\xec\x84\xa0\xeb\xac\xbc.html","path":"KODEX\xea\xb5\xac\xeb\xa6\xac\xec\x84\xa0\xeb\xac\xbc.html","'
#
# b'sha":"3b4b283b4fe361e493ceb0f51c007d041fb9b796","size":66698,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/conte'
#
# b'nts/KODEX%EA%B5%AC%EB%A6%AC%EC%84%A0%EB%AC%BC.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/mas'
#
# b'ter/KODEX%EA%B5%AC%EB%A6%AC%EC%84%A0%EB%AC%BC.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/'
#
# b'3b4b283b4fe361e493ceb0f51c007d041fb9b796","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/KOD'
#
# b'EX%EA%B5%AC%EB%A6%AC%EC%84%A0%EB%AC%BC.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github'
#
# b'.io/contents/KODEX%EA%B5%AC%EB%A6%AC%EC%84%A0%EB%AC%BC.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.gith'
#
# b'ub.io/git/blobs/3b4b283b4fe361e493ceb0f51c007d041fb9b796","html":"https://github.com/stockpy/stockpy.github.io/blob/master/KODEX'
#
# b'%EA%B5%AC%EB%A6%AC%EC%84%A0%EB%AC%BC.html"}},{"name":"KODEX\xec\x9b\x90\xec\x9c\xa0\xec\x84\xa0\xeb\xac\xbc.html","path":"KODEX\xec\x9b\x90\xec\x9c\xa0\xec\x84\xa0\xeb\xac\xbc.html","sha":"bedc08a0154'
#
# b'5d96785d94c663bae0f1ed52d1773","size":41870,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/KODEX%EC%9B%9'
#
# b'0%EC%9C%A0%EC%84%A0%EB%AC%BC.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/KODEX%EC%9B%9'
#
# b'0%EC%9C%A0%EC%84%A0%EB%AC%BC.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/bedc08a01545d9678'
#
# b'5d94c663bae0f1ed52d1773","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/KODEX%EC%9B%90%EC%9C'
#
# b'%A0%EC%84%A0%EB%AC%BC.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/KODE'
#
# b'X%EC%9B%90%EC%9C%A0%EC%84%A0%EB%AC%BC.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/b'
#
# b'edc08a01545d96785d94c663bae0f1ed52d1773","html":"https://github.com/stockpy/stockpy.github.io/blob/master/KODEX%EC%9B%90%EC%9C%A'
#
# b'0%EC%84%A0%EB%AC%BC.html"}},{"name":"KOSDAQ.txt","path":"KOSDAQ.txt","sha":"f1ad6dbda917251aff7529c9ea001bc3cdf1cbc6","size":251'
#
# b'72,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/KOSDAQ.txt?ref=master","html_url":"https://github.com/'
#
# b'stockpy/stockpy.github.io/blob/master/KOSDAQ.txt","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/f1'
#
# b'ad6dbda917251aff7529c9ea001bc3cdf1cbc6","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/KOSDA'
#
# b'Q.txt","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/KOSDAQ.txt?ref=master","g'
#
# b'it":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/f1ad6dbda917251aff7529c9ea001bc3cdf1cbc6","html":"https://'
#
# b'github.com/stockpy/stockpy.github.io/blob/master/KOSDAQ.txt"}},{"name":"KOSPI.txt","path":"KOSPI.txt","sha":"c49540ae701520fa348'
#
# b'35c59515ca912ccbac1be","size":26370,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/KOSPI.txt?ref=master"'
#
# b',"html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/KOSPI.txt","git_url":"https://api.github.com/repos/stockpy'
#
# b'/stockpy.github.io/git/blobs/c49540ae701520fa34835c59515ca912ccbac1be","download_url":"https://raw.githubusercontent.com/stockpy'
#
# b'/stockpy.github.io/master/KOSPI.txt","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/cont'
#
# b'ents/KOSPI.txt?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/c49540ae701520fa34835c59515ca'
#
# b'912ccbac1be","html":"https://github.com/stockpy/stockpy.github.io/blob/master/KOSPI.txt"}},{"name":"LICENSE.html","path":"LICENS'
#
# b'E.html","sha":"797423917806521df6f4611611bc402e14cf3c48","size":616,"url":"https://api.github.com/repos/stockpy/stockpy.github.i'
#
# b'o/contents/LICENSE.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/LICENSE.html","git_url"'
#
# b':"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/797423917806521df6f4611611bc402e14cf3c48","download_url":"htt'
#
# b'ps://raw.githubusercontent.com/stockpy/stockpy.github.io/master/LICENSE.html","type":"file","_links":{"self":"https://api.github'
#
# b'.com/repos/stockpy/stockpy.github.io/contents/LICENSE.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.githu'
#
# b'b.io/git/blobs/797423917806521df6f4611611bc402e14cf3c48","html":"https://github.com/stockpy/stockpy.github.io/blob/master/LICENS'
#
# b'E.html"}},{"name":"LOCKS.html","path":"LOCKS.html","sha":"9dff009eca774855aec47c7976e83b6bdf73eba6","size":659,"url":"https://ap'
#
# b'i.github.com/repos/stockpy/stockpy.github.io/contents/LOCKS.html?ref=master","html_url":"https://github.com/stockpy/stockpy.gith'
#
# b'ub.io/blob/master/LOCKS.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/9dff009eca774855aec47c'
#
# b'7976e83b6bdf73eba6","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/LOCKS.html","type":"file"'
#
# b',"_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/LOCKS.html?ref=master","git":"https://api.git'
#
# b'hub.com/repos/stockpy/stockpy.github.io/git/blobs/9dff009eca774855aec47c7976e83b6bdf73eba6","html":"https://github.com/stockpy/s'
#
# b'tockpy.github.io/blob/master/LOCKS.html"}},{"name":"Log","path":"Log","sha":"69a152c8167747776b916fc13d42ac89c1cdfae0","size":0,'
#
# b'"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Log?ref=master","html_url":"https://github.com/stockpy/st'
#
# b'ockpy.github.io/tree/master/Log","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/trees/69a152c8167747776b9'
#
# b'16fc13d42ac89c1cdfae0","download_url":null,"type":"dir","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io'
#
# b'/contents/Log?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/trees/69a152c8167747776b916fc13d42ac'
#
# b'89c1cdfae0","html":"https://github.com/stockpy/stockpy.github.io/tree/master/Log"}},{"name":"MEMORY.html","path":"MEMORY.html","'
#
# b'sha":"8aa46aed3225d75849f8ec139776dcede8cb62f9","size":1505,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/conten'
#
# b'ts/MEMORY.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/MEMORY.html","git_url":"https://'
#
# b'api.github.com/repos/stockpy/stockpy.github.io/git/blobs/8aa46aed3225d75849f8ec139776dcede8cb62f9","download_url":"https://raw.g'
#
# b'ithubusercontent.com/stockpy/stockpy.github.io/master/MEMORY.html","type":"file","_links":{"self":"https://api.github.com/repos/'
#
# b'stockpy/stockpy.github.io/contents/MEMORY.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blo'
#
# b'bs/8aa46aed3225d75849f8ec139776dcede8cb62f9","html":"https://github.com/stockpy/stockpy.github.io/blob/master/MEMORY.html"}},{"n'
#
# b'ame":"MiniCheck.py","path":"MiniCheck.py","sha":"b7ebe316075e049db3648632184214b8b1a62c44","size":3468,"url":"https://api.github'
#
# b'.com/repos/stockpy/stockpy.github.io/contents/MiniCheck.py?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/'
#
# b'blob/master/MiniCheck.py","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/b7ebe316075e049db364863218'
#
# b'4214b8b1a62c44","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/MiniCheck.py","type":"file","'
#
# b'_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/MiniCheck.py?ref=master","git":"https://api.git'
#
# b'hub.com/repos/stockpy/stockpy.github.io/git/blobs/b7ebe316075e049db3648632184214b8b1a62c44","html":"https://github.com/stockpy/s'
#
# b'tockpy.github.io/blob/master/MiniCheck.py"}},{"name":"MiniCheck_BB.py","path":"MiniCheck_BB.py","sha":"7d4ea09c0d9e4bb0f14c8db4a'
#
# b'cea0c84521334c1","size":5921,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/MiniCheck_BB.py?ref=master",'
#
# b'"html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/MiniCheck_BB.py","git_url":"https://api.github.com/repos/st'
#
# b'ockpy/stockpy.github.io/git/blobs/7d4ea09c0d9e4bb0f14c8db4acea0c84521334c1","download_url":"https://raw.githubusercontent.com/st'
#
# b'ockpy/stockpy.github.io/master/MiniCheck_BB.py","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.git'
#
# b'hub.io/contents/MiniCheck_BB.py?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/7d4ea09c0d9e'
#
# b'4bb0f14c8db4acea0c84521334c1","html":"https://github.com/stockpy/stockpy.github.io/blob/master/MiniCheck_BB.py"}},{"name":"MiniC'
#
# b'heck_Inform.html","path":"MiniCheck_Inform.html","sha":"8c720dbcfc3475ff812a4c6469e4ede15f24cf08","size":645,"url":"https://api.'
#
# b'github.com/repos/stockpy/stockpy.github.io/contents/MiniCheck_Inform.html?ref=master","html_url":"https://github.com/stockpy/sto'
#
# b'ckpy.github.io/blob/master/MiniCheck_Inform.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/8c'
#
# b'720dbcfc3475ff812a4c6469e4ede15f24cf08","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/MiniC'
#
# b'heck_Inform.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/MiniCheck_Info'
#
# b'rm.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/8c720dbcfc3475ff812a4c6469e4ede15f24'
#
# b'cf08","html":"https://github.com/stockpy/stockpy.github.io/blob/master/MiniCheck_Inform.html"}},{"name":"New_Chart.ipynb","path"'
#
# b':"New_Chart.ipynb","sha":"d26635664a37b0c645c04d31faca697261cf10a7","size":15945,"url":"https://api.github.com/repos/stockpy/sto'
#
# b'ckpy.github.io/contents/New_Chart.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/New_Cha'
#
# b'rt.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/d26635664a37b0c645c04d31faca697261cf10a7",'
#
# b'"download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/New_Chart.ipynb","type":"file","_links":{"sel'
#
# b'f":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/New_Chart.ipynb?ref=master","git":"https://api.github.com/re'
#
# b'pos/stockpy/stockpy.github.io/git/blobs/d26635664a37b0c645c04d31faca697261cf10a7","html":"https://github.com/stockpy/stockpy.git'
#
# b'hub.io/blob/master/New_Chart.ipynb"}},{"name":"New_Echart_Test_1.html","path":"New_Echart_Test_1.html","sha":"e4f339706b37023789'
#
# b'7d1288069594374e111cbb","size":1121,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/New_Echart_Test_1.htm'
#
# b'l?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/New_Echart_Test_1.html","git_url":"https://ap'
#
# b'i.github.com/repos/stockpy/stockpy.github.io/git/blobs/e4f339706b370237897d1288069594374e111cbb","download_url":"https://raw.git'
#
# b'hubusercontent.com/stockpy/stockpy.github.io/master/New_Echart_Test_1.html","type":"file","_links":{"self":"https://api.github.c'
#
# b'om/repos/stockpy/stockpy.github.io/contents/New_Echart_Test_1.html?ref=master","git":"https://api.github.com/repos/stockpy/stock'
#
# b'py.github.io/git/blobs/e4f339706b370237897d1288069594374e111cbb","html":"https://github.com/stockpy/stockpy.github.io/blob/maste'
#
# b'r/New_Echart_Test_1.html"}},{"name":"OBJECTS.html","path":"OBJECTS.html","sha":"3381dd48610d0bc032d38646d802fe5b4ee4df5c","size"'
#
# b':632,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/OBJECTS.html?ref=master","html_url":"https://github.'
#
# b'com/stockpy/stockpy.github.io/blob/master/OBJECTS.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/bl'
#
# b'obs/3381dd48610d0bc032d38646d802fe5b4ee4df5c","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master'
#
# b'/OBJECTS.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/OBJECTS.html?ref='
#
# b'master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/3381dd48610d0bc032d38646d802fe5b4ee4df5c","html"'
#
# b':"https://github.com/stockpy/stockpy.github.io/blob/master/OBJECTS.html"}},{"name":"OPRATION_SYSTEM.html","path":"OPRATION_SYSTE'
#
# b'M.html","sha":"2036d65dd9e2601c41d408748ff736550be9a97e","size":942,"url":"https://api.github.com/repos/stockpy/stockpy.github.i'
#
# b'o/contents/OPRATION_SYSTEM.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/OPRATION_SYSTEM'
#
# b'.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/2036d65dd9e2601c41d408748ff736550be9a97e","do'
#
# b'wnload_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/OPRATION_SYSTEM.html","type":"file","_links":{"s'
#
# b'elf":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/OPRATION_SYSTEM.html?ref=master","git":"https://api.github'
#
# b'.com/repos/stockpy/stockpy.github.io/git/blobs/2036d65dd9e2601c41d408748ff736550be9a97e","html":"https://github.com/stockpy/stoc'
#
# b'kpy.github.io/blob/master/OPRATION_SYSTEM.html"}},{"name":"OS_Python_restart.ipynb","path":"OS_Python_restart.ipynb","sha":"c17d'
#
# b'9c949385eafbd50ccbc7f92326337ef93f30","size":1123,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/OS_Pyth'
#
# b'on_restart.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/OS_Python_restart.ipynb","git_'
#
# b'url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/c17d9c949385eafbd50ccbc7f92326337ef93f30","download_url":'
#
# b'"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/OS_Python_restart.ipynb","type":"file","_links":{"self":"htt'
#
# b'ps://api.github.com/repos/stockpy/stockpy.github.io/contents/OS_Python_restart.ipynb?ref=master","git":"https://api.github.com/r'
#
# b'epos/stockpy/stockpy.github.io/git/blobs/c17d9c949385eafbd50ccbc7f92326337ef93f30","html":"https://github.com/stockpy/stockpy.gi'
#
# b'thub.io/blob/master/OS_Python_restart.ipynb"}},{"name":"README.md","path":"README.md","sha":"fbfc4d3d2f9858ba324ab30425e2e817f38'
#
# b'f28be","size":87,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/README.md?ref=master","html_url":"https:'
#
# b'//github.com/stockpy/stockpy.github.io/blob/master/README.md","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/'
#
# b'git/blobs/fbfc4d3d2f9858ba324ab30425e2e817f38f28be","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/'
#
# b'master/README.md","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/README.md?ref='
#
# b'master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/fbfc4d3d2f9858ba324ab30425e2e817f38f28be","html"'
#
# b':"https://github.com/stockpy/stockpy.github.io/blob/master/README.md"}},{"name":"Start_Stock.bat","path":"Start_Stock.bat","sha"'
#
# b':"a8f75829f4c0bb2ca471e2924b39eb3328e2fdaf","size":76,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Sta'
#
# b'rt_Stock.bat?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Start_Stock.bat","git_url":"https:'
#
# b'//api.github.com/repos/stockpy/stockpy.github.io/git/blobs/a8f75829f4c0bb2ca471e2924b39eb3328e2fdaf","download_url":"https://raw'
#
# b'.githubusercontent.com/stockpy/stockpy.github.io/master/Start_Stock.bat","type":"file","_links":{"self":"https://api.github.com/'
#
# b'repos/stockpy/stockpy.github.io/contents/Start_Stock.bat?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.'
#
# b'io/git/blobs/a8f75829f4c0bb2ca471e2924b39eb3328e2fdaf","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Start_St'
#
# b'ock.bat"}},{"name":"StockToday.html","path":"StockToday.html","sha":"7ddaebc7071543fd54ba1f1a5188cf83a8570b4c","size":796845,"ur'
#
# b'l":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/StockToday.html?ref=master","html_url":"https://github.com/s'
#
# b'tockpy/stockpy.github.io/blob/master/StockToday.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blob'
#
# b's/7ddaebc7071543fd54ba1f1a5188cf83a8570b4c","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/S'
#
# b'tockToday.html","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/StockToday.html?'
#
# b'ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/7ddaebc7071543fd54ba1f1a5188cf83a8570b4c","h'
#
# b'tml":"https://github.com/stockpy/stockpy.github.io/blob/master/StockToday.html"}},{"name":"StockToday_20210217_\xec\x9d\xb4\xec\x9c\xa0\xec\x97\x86\xec\x9d\xb4 \xeb\xa9\x88\xec'
#
# b'\xb6\xa4.html","path":"StockToday_20210217_\xec\x9d\xb4\xec\x9c\xa0\xec\x97\x86\xec\x9d\xb4 \xeb\xa9\x88\xec\xb6\xa4.html","sha":"34ef054c8dd7a8f0ff31fb1ab768b249fab8133f","size":784330,"u'
#
# b'rl":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/StockToday_20210217_%EC%9D%B4%EC%9C%A0%EC%97%86%EC%9D%B4%20'
#
# b'%EB%A9%88%EC%B6%A4.html?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/StockToday_20210217_%EC'
#
# b'%9D%B4%EC%9C%A0%EC%97%86%EC%9D%B4%20%EB%A9%88%EC%B6%A4.html","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/g'
#
# b'it/blobs/34ef054c8dd7a8f0ff31fb1ab768b249fab8133f","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/m'
#
# b'aster/StockToday_20210217_%EC%9D%B4%EC%9C%A0%EC%97%86%EC%9D%B4%20%EB%A9%88%EC%B6%A4.html","type":"file","_links":{"self":"https:'
#
# b'//api.github.com/repos/stockpy/stockpy.github.io/contents/StockToday_20210217_%EC%9D%B4%EC%9C%A0%EC%97%86%EC%9D%B4%20%EB%A9%88%E'
#
# b'C%B6%A4.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/34ef054c8dd7a8f0ff31fb1ab768b24'
#
# b'9fab8133f","html":"https://github.com/stockpy/stockpy.github.io/blob/master/StockToday_20210217_%EC%9D%B4%EC%9C%A0%EC%97%86%EC%9'
#
# b'D%B4%20%EB%A9%88%EC%B6%A4.html"}},{"name":"Stock_Conn.ipynb","path":"Stock_Conn.ipynb","sha":"d99a18fbf9b57d4c22833dce4965434d50'
#
# b'c19f07","size":16538,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Conn.ipynb?ref=master","html_u'
#
# b'rl":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Conn.ipynb","git_url":"https://api.github.com/repos/stockpy/'
#
# b'stockpy.github.io/git/blobs/d99a18fbf9b57d4c22833dce4965434d50c19f07","download_url":"https://raw.githubusercontent.com/stockpy/'
#
# b'stockpy.github.io/master/Stock_Conn.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.i'
#
# b'o/contents/Stock_Conn.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/d99a18fbf9b57d4c'
#
# b'22833dce4965434d50c19f07","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Conn.ipynb"}},{"name":"Stock_Hi'
#
# b'story.py","path":"Stock_History.py","sha":"36b60b83057bacbc66fe32b6e369218107d0a5fd","size":9623,"url":"https://api.github.com/r'
#
# b'epos/stockpy/stockpy.github.io/contents/Stock_History.py?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/bl'
#
# b'ob/master/Stock_History.py","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/36b60b83057bacbc66fe32b6'
#
# b'e369218107d0a5fd","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Stock_History.py","type":"f'
#
# b'ile","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_History.py?ref=master","git":"https'
#
# b'://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/36b60b83057bacbc66fe32b6e369218107d0a5fd","html":"https://github.com'
#
# b'/stockpy/stockpy.github.io/blob/master/Stock_History.py"}},{"name":"Stock_Main.ipynb","path":"Stock_Main.ipynb","sha":"739d6b55a'
#
# b'e03c4c028cd8e01a8e7f5c566bc1070","size":35114,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main.'
#
# b'ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main.ipynb","git_url":"https://api.'
#
# b'github.com/repos/stockpy/stockpy.github.io/git/blobs/739d6b55ae03c4c028cd8e01a8e7f5c566bc1070","download_url":"https://raw.githu'
#
# b'busercontent.com/stockpy/stockpy.github.io/master/Stock_Main.ipynb","type":"file","_links":{"self":"https://api.github.com/repos'
#
# b'/stockpy/stockpy.github.io/contents/Stock_Main.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/g'
#
# b'it/blobs/739d6b55ae03c4c028cd8e01a8e7f5c566bc1070","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main.i'
#
# b'pynb"}},{"name":"Stock_Main.py","path":"Stock_Main.py","sha":"5af1d576a93e68cb8f9864433cbe7306488f574c","size":26498,"url":"http'
#
# b's://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main.py?ref=master","html_url":"https://github.com/stockpy/sto'
#
# b'ckpy.github.io/blob/master/Stock_Main.py","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/5af1d576a9'
#
# b'3e68cb8f9864433cbe7306488f574c","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Stock_Main.py'
#
# b'","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main.py?ref=master","git'
#
# b'":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/5af1d576a93e68cb8f9864433cbe7306488f574c","html":"https://gi'
#
# b'thub.com/stockpy/stockpy.github.io/blob/master/Stock_Main.py"}},{"name":"Stock_Main_Pandas.py","path":"Stock_Main_Pandas.py","sh'
#
# b'a":"fc322e6104c90cd052c9b8e062c2e9d071a7b35c","size":34171,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/content'
#
# b's/Stock_Main_Pandas.py?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas.py","g'
#
# b'it_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/fc322e6104c90cd052c9b8e062c2e9d071a7b35c","download_ur'
#
# b'l":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Stock_Main_Pandas.py","type":"file","_links":{"self":"htt'
#
# b'ps://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main_Pandas.py?ref=master","git":"https://api.github.com/repo'
#
# b's/stockpy/stockpy.github.io/git/blobs/fc322e6104c90cd052c9b8e062c2e9d071a7b35c","html":"https://github.com/stockpy/stockpy.githu'
#
# b'b.io/blob/master/Stock_Main_Pandas.py"}},{"name":"Stock_Main_Pandas_20200721.ipynb","path":"Stock_Main_Pandas_20200721.ipynb","s'
#
# b'ha":"037e0ad85a9f3c747f7b293c7cc1c8ee67a2e783","size":111597,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/conte'
#
# b'nts/Stock_Main_Pandas_20200721.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main'
#
# b'_Pandas_20200721.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/037e0ad85a9f3c747f7b293c7cc1'
#
# b'c8ee67a2e783","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Stock_Main_Pandas_20200721.ipyn'
#
# b'b","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main_Pandas_20200721.ip'
#
# b'ynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/037e0ad85a9f3c747f7b293c7cc1c8ee67a2e783'
#
# b'","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas_20200721.ipynb"}},{"name":"Stock_Main_Panda'
#
# b's_20200723.ipynb","path":"Stock_Main_Pandas_20200723.ipynb","sha":"33b877d9aed9c8fe760e7ac1fb7ff0d34491a50d","size":1429747,"url'
#
# b'":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main_Pandas_20200723.ipynb?ref=master","html_url":"http'
#
# b's://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas_20200723.ipynb","git_url":"https://api.github.com/repos/s'
#
# b'tockpy/stockpy.github.io/git/blobs/33b877d9aed9c8fe760e7ac1fb7ff0d34491a50d","download_url":"https://raw.githubusercontent.com/s'
#
# b'tockpy/stockpy.github.io/master/Stock_Main_Pandas_20200723.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/s'
#
# b'tockpy/stockpy.github.io/contents/Stock_Main_Pandas_20200723.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stock'
#
# b'py.github.io/git/blobs/33b877d9aed9c8fe760e7ac1fb7ff0d34491a50d","html":"https://github.com/stockpy/stockpy.github.io/blob/maste'
#
# b'r/Stock_Main_Pandas_20200723.ipynb"}},{"name":"Stock_Main_Pandas_20200803.ipynb","path":"Stock_Main_Pandas_20200803.ipynb","sha"'
#
# b':"6bbb14cedfc88b90c52df2566f24665ea2259f49","size":86314,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/'
#
# b'Stock_Main_Pandas_20200803.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pan'
#
# b'das_20200803.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/6bbb14cedfc88b90c52df2566f24665e'
#
# b'a2259f49","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Stock_Main_Pandas_20200803.ipynb","'
#
# b'type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main_Pandas_20200803.ipynb?'
#
# b'ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/6bbb14cedfc88b90c52df2566f24665ea2259f49","h'
#
# b'tml":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas_20200803.ipynb"}},{"name":"Stock_Main_Pandas_20'
#
# b'200808.ipynb","path":"Stock_Main_Pandas_20200808.ipynb","sha":"cfa7a85843b46d3d04cce20016f375211f02b273","size":102414,"url":"ht'
#
# b'tps://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main_Pandas_20200808.ipynb?ref=master","html_url":"https://g'
#
# b'ithub.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas_20200808.ipynb","git_url":"https://api.github.com/repos/stockp'
#
# b'y/stockpy.github.io/git/blobs/cfa7a85843b46d3d04cce20016f375211f02b273","download_url":"https://raw.githubusercontent.com/stockp'
#
# b'y/stockpy.github.io/master/Stock_Main_Pandas_20200808.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/stockp'
#
# b'y/stockpy.github.io/contents/Stock_Main_Pandas_20200808.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.gi'
#
# b'thub.io/git/blobs/cfa7a85843b46d3d04cce20016f375211f02b273","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Sto'
#
# b'ck_Main_Pandas_20200808.ipynb"}},{"name":"Stock_Main_Pandas_20200811_1\xec\xb0\xa8\xec\x99\x84\xeb\xa3\x8c.ipynb","path":"Stock_Main_Pandas_20200811_1\xec\xb0\xa8\xec\x99'
#
# b'\x84\xeb\xa3\x8c.ipynb","sha":"ae4726cd4beb6965ec3ecb51935b9c785f60386c","size":2123080,"url":"https://api.github.com/repos/stockpy/stockpy.'
#
# b'github.io/contents/Stock_Main_Pandas_20200811_1%EC%B0%A8%EC%99%84%EB%A3%8C.ipynb?ref=master","html_url":"https://github.com/stoc'
#
# b'kpy/stockpy.github.io/blob/master/Stock_Main_Pandas_20200811_1%EC%B0%A8%EC%99%84%EB%A3%8C.ipynb","git_url":"https://api.github.c'
#
# b'om/repos/stockpy/stockpy.github.io/git/blobs/ae4726cd4beb6965ec3ecb51935b9c785f60386c","download_url":"https://raw.githubusercon'
#
# b'tent.com/stockpy/stockpy.github.io/master/Stock_Main_Pandas_20200811_1%EC%B0%A8%EC%99%84%EB%A3%8C.ipynb","type":"file","_links":'
#
# b'{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main_Pandas_20200811_1%EC%B0%A8%EC%99%84%EB%A3%8C'
#
# b'.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/ae4726cd4beb6965ec3ecb51935b9c785f603'
#
# b'86c","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas_20200811_1%EC%B0%A8%EC%99%84%EB%A3%8C.ip'
#
# b'ynb"}},{"name":"Stock_Main_Pandas_AutoStart.html","path":"Stock_Main_Pandas_AutoStart.html","sha":"8b754c86dd58e0dc2c4839be26360'
#
# b'f62b706f280","size":2007540,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main_Pandas_AutoStart.h'
#
# b'tml?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas_AutoStart.html","git_url"'
#
# b':"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/8b754c86dd58e0dc2c4839be26360f62b706f280","download_url":"htt'
#
# b'ps://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Stock_Main_Pandas_AutoStart.html","type":"file","_links":{"self"'
#
# b':"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Main_Pandas_AutoStart.html?ref=master","git":"https://ap'
#
# b'i.github.com/repos/stockpy/stockpy.github.io/git/blobs/8b754c86dd58e0dc2c4839be26360f62b706f280","html":"https://github.com/stoc'
#
# b'kpy/stockpy.github.io/blob/master/Stock_Main_Pandas_AutoStart.html"}},{"name":"Stock_Main_Pandas_AutoStart.ipynb","path":"Stock_'
#
# b'Main_Pandas_AutoStart.ipynb","sha":"638c1e1ae3286af900c19ed191531056f0eede3d","size":169658,"url":"https://api.github.com/repos/'
#
# b'stockpy/stockpy.github.io/contents/Stock_Main_Pandas_AutoStart.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.'
#
# b'github.io/blob/master/Stock_Main_Pandas_AutoStart.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/b'
#
# b'lobs/638c1e1ae3286af900c19ed191531056f0eede3d","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/maste'
#
# b'r/Stock_Main_Pandas_AutoStart.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/cont'
#
# b'ents/Stock_Main_Pandas_AutoStart.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/638c1'
#
# b'e1ae3286af900c19ed191531056f0eede3d","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas_AutoStar'
#
# b't.ipynb"}},{"name":"Stock_Main_Pandas_AutoStart_20200814.ipynb","path":"Stock_Main_Pandas_AutoStart_20200814.ipynb","sha":"62833'
#
# b'589b23df5e04c108f5f181e901687767146","size":364765,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_'
#
# b'Main_Pandas_AutoStart_20200814.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main'
#
# b'_Pandas_AutoStart_20200814.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/62833589b23df5e04c'
#
# b'108f5f181e901687767146","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/Stock_Main_Pandas_Aut'
#
# b'oStart_20200814.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/Stock_Mai'
#
# b'n_Pandas_AutoStart_20200814.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/62833589b2'
#
# b'3df5e04c108f5f181e901687767146","html":"https://github.com/stockpy/stockpy.github.io/blob/master/Stock_Main_Pandas_AutoStart_202'
#
# ...
#
# b'd8643f3296ec23cc207b1028163f6","size":735,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/token.pickle?re'
#
# b'f=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/token.pickle","git_url":"https://api.github.com/r'
#
# b'epos/stockpy/stockpy.github.io/git/blobs/a2defb051a7d8643f3296ec23cc207b1028163f6","download_url":"https://raw.githubusercontent'
#
# b'.com/stockpy/stockpy.github.io/master/token.pickle","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy'
#
# b'.github.io/contents/token.pickle?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/a2defb051a7'
#
# b'd8643f3296ec23cc207b1028163f6","html":"https://github.com/stockpy/stockpy.github.io/blob/master/token.pickle"}},{"name":"token.p'
#
# b'ickle \xeb\xb3\xb5\xec\x82\xac\xeb\xb3\xb8","path":"token.pickle \xeb\xb3\xb5\xec\x82\xac\xeb\xb3\xb8","sha":"a24aa1b63b4c4c70351bbaa63251d2d614050654","size":750,"url":"https://api.'
#
# b'github.com/repos/stockpy/stockpy.github.io/contents/token.pickle%20%EB%B3%B5%EC%82%AC%EB%B3%B8?ref=master","html_url":"https://g'
#
# b'ithub.com/stockpy/stockpy.github.io/blob/master/token.pickle%20%EB%B3%B5%EC%82%AC%EB%B3%B8","git_url":"https://api.github.com/re'
#
# b'pos/stockpy/stockpy.github.io/git/blobs/a24aa1b63b4c4c70351bbaa63251d2d614050654","download_url":"https://raw.githubusercontent.'
#
# b'com/stockpy/stockpy.github.io/master/token.pickle%20%EB%B3%B5%EC%82%AC%EB%B3%B8","type":"file","_links":{"self":"https://api.git'
#
# b'hub.com/repos/stockpy/stockpy.github.io/contents/token.pickle%20%EB%B3%B5%EC%82%AC%EB%B3%B8?ref=master","git":"https://api.githu'
#
# b'b.com/repos/stockpy/stockpy.github.io/git/blobs/a24aa1b63b4c4c70351bbaa63251d2d614050654","html":"https://github.com/stockpy/sto'
#
# b'ckpy.github.io/blob/master/token.pickle%20%EB%B3%B5%EC%82%AC%EB%B3%B8"}},{"name":"venv","path":"venv","sha":"33bbe3e68a7f820ada1'
#
# b'825bc09deb00973f6218b","size":0,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/venv?ref=master","html_ur'
#
# b'l":"https://github.com/stockpy/stockpy.github.io/tree/master/venv","git_url":"https://api.github.com/repos/stockpy/stockpy.githu'
#
# b'b.io/git/trees/33bbe3e68a7f820ada1825bc09deb00973f6218b","download_url":null,"type":"dir","_links":{"self":"https://api.github.c'
#
# b'om/repos/stockpy/stockpy.github.io/contents/venv?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/t'
#
# b'rees/33bbe3e68a7f820ada1825bc09deb00973f6218b","html":"https://github.com/stockpy/stockpy.github.io/tree/master/venv"}},{"name":'
#
# b'"\xeb\xa7\x88\xed\x81\xac\xeb\xa1\x9c\xec\xa0\xa0_20210425.html","path":"\xeb\xa7\x88\xed\x81\xac\xeb\xa1\x9c\xec\xa0\xa0_20210425.html","sha":"ce73fb349a65bf7c5ff0dd4d6ae03b2413c0f20c","size":7887,"u'
#
# b'rl":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_20210425.html?ref=mast'
#
# b'er","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_20210425.html","gi'
#
# b't_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/ce73fb349a65bf7c5ff0dd4d6ae03b2413c0f20c","download_url'
#
# b'":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_20210425.html","type"'
#
# b':"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_2'
#
# b'0210425.html?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/ce73fb349a65bf7c5ff0dd4d6ae03b2'
#
# b'413c0f20c","html":"https://github.com/stockpy/stockpy.github.io/blob/master/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_20210425.html"}'
#
# b'},{"name":"\xeb\xa7\x88\xed\x81\xac\xeb\xa1\x9c\xec\xa0\xa0_20210425.txt","path":"\xeb\xa7\x88\xed\x81\xac\xeb\xa1\x9c\xec\xa0\xa0_20210425.txt","sha":"68048d8c756de4de7afcfcd5c6de63e7a8650b1c","size"'
#
# b':152832,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_20210425.txt'
#
# b'?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_20210425.'
#
# b'txt","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/68048d8c756de4de7afcfcd5c6de63e7a8650b1c","down'
#
# b'load_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_20210425.txt"'
#
# b',"type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%'
#
# b'A0%A0_20210425.txt?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/68048d8c756de4de7afcfcd5c'
#
# b'6de63e7a8650b1c","html":"https://github.com/stockpy/stockpy.github.io/blob/master/%EB%A7%88%ED%81%AC%EB%A1%9C%EC%A0%A0_20210425.'
#
# b'txt"}},{"name":"\xec\x82\xbc\xec\x84\xb1\xec\xa0\x84\xec\x9e\x90_\xec\x9d\xbc\xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0.ipynb","path":"\xec\x82\xbc\xec\x84\xb1\xec\xa0\x84\xec\x9e\x90_\xec\x9d\xbc\xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0.ipynb","sha":"377152ef7a39f621641068a27e89d84'
#
# b'5a8b80d8f","size":8840,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%'
#
# b'90_%EC%9D%BC%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/%'
#
# b'EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90_%EC%9D%BC%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb","git_url":"https://api.github.com/repos/stockpy/'
#
# b'stockpy.github.io/git/blobs/377152ef7a39f621641068a27e89d845a8b80d8f","download_url":"https://raw.githubusercontent.com/stockpy/'
#
# b'stockpy.github.io/master/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90_%EC%9D%BC%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb","type":"file","_links"'
#
# b':{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90_%EC%9D%BC%EB%8D%B'
#
# b'0%EC%9D%B4%ED%84%B0.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/377152ef7a39f62164'
#
# b'1068a27e89d845a8b80d8f","html":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90_%E'
#
# b'C%9D%BC%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb"}},{"name":"\xec\x83\x88 \xed\x85\x8d\xec\x8a\xa4\xed\x8a\xb8 \xeb\xac\xb8\xec\x84\x9c.txt","path":"\xec\x83\x88 \xed\x85\x8d\xec\x8a\xa4\xed\x8a\xb8 \xeb\xac\xb8\xec\x84\x9c.txt","sha":"e69de29b'
#
# b'b2d1d6434b8b29ae775ad8c2e48c5391","size":0,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%83%88%20%E'
#
# b'D%85%8D%EC%8A%A4%ED%8A%B8%20%EB%AC%B8%EC%84%9C.txt?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/mas'
#
# b'ter/%EC%83%88%20%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%AC%B8%EC%84%9C.txt","git_url":"https://api.github.com/repos/stockpy/stockpy.gi'
#
# b'thub.io/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.gi'
#
# b'thub.io/master/%EC%83%88%20%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%AC%B8%EC%84%9C.txt","type":"file","_links":{"self":"https://api.git'
#
# b'hub.com/repos/stockpy/stockpy.github.io/contents/%EC%83%88%20%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%AC%B8%EC%84%9C.txt?ref=master","g'
#
# b'it":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/e69de29bb2d1d6434b8b29ae775ad8c2e48c5391","html":"https://'
#
# b'github.com/stockpy/stockpy.github.io/blob/master/%EC%83%88%20%ED%85%8D%EC%8A%A4%ED%8A%B8%20%EB%AC%B8%EC%84%9C.txt"}},{"name":"\xec\x9a'
#
# b'\xb0\xec\x84\xa0\xec\xa3\xbc_\xec\xa0\x84\xeb\x9e\xb5.ipynb","path":"\xec\x9a\xb0\xec\x84\xa0\xec\xa3\xbc_\xec\xa0\x84\xeb\x9e\xb5.ipynb","sha":"51a84985c151c84cfd77d55f0105870afb264dbf","size":15283,"url":"https'
#
# b'://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%9A%B0%EC%84%A0%EC%A3%BC_%EC%A0%84%EB%9E%B5.ipynb?ref=master","htm'
#
# b'l_url":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%9A%B0%EC%84%A0%EC%A3%BC_%EC%A0%84%EB%9E%B5.ipynb","git_url"'
#
# b':"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/51a84985c151c84cfd77d55f0105870afb264dbf","download_url":"htt'
#
# b'ps://raw.githubusercontent.com/stockpy/stockpy.github.io/master/%EC%9A%B0%EC%84%A0%EC%A3%BC_%EC%A0%84%EB%9E%B5.ipynb","type":"fi'
#
# b'le","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%9A%B0%EC%84%A0%EC%A3%BC_%EC%A0%84%EB%9'
#
# b'E%B5.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/51a84985c151c84cfd77d55f0105870af'
#
# b'b264dbf","html":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%9A%B0%EC%84%A0%EC%A3%BC_%EC%A0%84%EB%9E%B5.ipynb"}'
#
# b'},{"name":"\xec\xa2\x85\xeb\xaa\xa9\xec\x83\x81\xec\x84\xb8\xec\xa1\xb0\xed\x9a\x8c_PER_ROE_ETC.ipynb","path":"\xec\xa2\x85\xeb\xaa\xa9\xec\x83\x81\xec\x84\xb8\xec\xa1\xb0\xed\x9a\x8c_PER_ROE_ETC.ipynb","sha":"33d31e55c2483e29f0d4ce93e9'
#
# b'890560ec6387cb","size":7977,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%A2%85%EB%AA%A9%EC%83%81%E'
#
# b'C%84%B8%EC%A1%B0%ED%9A%8C_PER_ROE_ETC.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC'
#
# b'%A2%85%EB%AA%A9%EC%83%81%EC%84%B8%EC%A1%B0%ED%9A%8C_PER_ROE_ETC.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.g'
#
# b'ithub.io/git/blobs/33d31e55c2483e29f0d4ce93e9890560ec6387cb","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.g'
#
# b'ithub.io/master/%EC%A2%85%EB%AA%A9%EC%83%81%EC%84%B8%EC%A1%B0%ED%9A%8C_PER_ROE_ETC.ipynb","type":"file","_links":{"self":"https:'
#
# b'//api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%A2%85%EB%AA%A9%EC%83%81%EC%84%B8%EC%A1%B0%ED%9A%8C_PER_ROE_ETC.ipy'
#
# b'nb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/33d31e55c2483e29f0d4ce93e9890560ec6387cb"'
#
# b',"html":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%A2%85%EB%AA%A9%EC%83%81%EC%84%B8%EC%A1%B0%ED%9A%8C_PER_ROE'
#
# b'_ETC.ipynb"}},{"name":"\xec\xa3\xbc\xec\x8b\x9d\xec\x9e\x94\xea\xb3\xa02.ipynb","path":"\xec\xa3\xbc\xec\x8b\x9d\xec\x9e\x94\xea\xb3\xa02.ipynb","sha":"cc80b0c60dcaf118c8cef4253e272c9804cab9eb","size"'
#
# b':61653,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%A3%BC%EC%8B%9D%EC%9E%94%EA%B3%A02.ipynb?ref=ma'
#
# b'ster","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%9E%94%EA%B3%A02.ipynb","git_url'
#
# b'":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/cc80b0c60dcaf118c8cef4253e272c9804cab9eb","download_url":"ht'
#
# b'tps://raw.githubusercontent.com/stockpy/stockpy.github.io/master/%EC%A3%BC%EC%8B%9D%EC%9E%94%EA%B3%A02.ipynb","type":"file","_li'
#
# b'nks":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%A3%BC%EC%8B%9D%EC%9E%94%EA%B3%A02.ipynb?ref=ma'
#
# b'ster","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/cc80b0c60dcaf118c8cef4253e272c9804cab9eb","html":"'
#
# b'https://github.com/stockpy/stockpy.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%9E%94%EA%B3%A02.ipynb"}},{"name":"\xec\xa3\xbc\xec\x8b\x9d\xec\xa2\x85\xeb\xaa\xa9\xec\xa1\xb0'
#
# b'\xed\x9a\x8c.ipynb","path":"\xec\xa3\xbc\xec\x8b\x9d\xec\xa2\x85\xeb\xaa\xa9\xec\xa1\xb0\xed\x9a\x8c.ipynb","sha":"f4b9e6a0edc10dc5b307a0107ae4f8e48b942a93","size":2203,"url":"https://api.git'
#
# b'hub.com/repos/stockpy/stockpy.github.io/contents/%EC%A3%BC%EC%8B%9D%EC%A2%85%EB%AA%A9%EC%A1%B0%ED%9A%8C.ipynb?ref=master","html_'
#
# b'url":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%A2%85%EB%AA%A9%EC%A1%B0%ED%9A%8C.ipynb","gi'
#
# b't_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/f4b9e6a0edc10dc5b307a0107ae4f8e48b942a93","download_url'
#
# b'":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/%EC%A3%BC%EC%8B%9D%EC%A2%85%EB%AA%A9%EC%A1%B0%ED%9A%8C.ipy'
#
# b'nb","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%A3%BC%EC%8B%9D%EC%A2%85%'
#
# b'EB%AA%A9%EC%A1%B0%ED%9A%8C.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/f4b9e6a0edc'
#
# b'10dc5b307a0107ae4f8e48b942a93","html":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%A2%85%EB%A'
#
# b'A%A9%EC%A1%B0%ED%9A%8C.ipynb"}},{"name":"\xec\xa3\xbc\xec\x8b\x9d\xec\xa3\xbc\xeb\xac\xb8.ipynb","path":"\xec\xa3\xbc\xec\x8b\x9d\xec\xa3\xbc\xeb\xac\xb8.ipynb","sha":"637ea0e8340594a7d674f97decc6a236'
#
# b'a54177de","size":13314,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%A3%BC%EC%8B%9D%EC%A3%BC%EB%AC%'
#
# b'B8.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%A3%BC%EB%AC%B8.i'
#
# b'pynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/637ea0e8340594a7d674f97decc6a236a54177de","dow'
#
# b'nload_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/%EC%A3%BC%EC%8B%9D%EC%A3%BC%EB%AC%B8.ipynb","type'
#
# b'":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%EC%A3%BC%EC%8B%9D%EC%A3%BC%EB%AC%B8.'
#
# b'ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/637ea0e8340594a7d674f97decc6a236a54177'
#
# b'de","html":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%A3%BC%EB%AC%B8.ipynb"}},{"name":"\xec\xa3\xbc\xec'
#
# b'\x8b\x9d\xec\xb0\xa8\xed\x8a\xb8.ipynb","path":"\xec\xa3\xbc\xec\x8b\x9d\xec\xb0\xa8\xed\x8a\xb8.ipynb","sha":"233190c485cdcaddd9665ddc2bc8ca7b5859beef","size":3198,"url":"https://api.gith'
#
# b'ub.com/repos/stockpy/stockpy.github.io/contents/%EC%A3%BC%EC%8B%9D%EC%B0%A8%ED%8A%B8.ipynb?ref=master","html_url":"https://githu'
#
# b'b.com/stockpy/stockpy.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%B0%A8%ED%8A%B8.ipynb","git_url":"https://api.github.com/repos/'
#
# b'stockpy/stockpy.github.io/git/blobs/233190c485cdcaddd9665ddc2bc8ca7b5859beef","download_url":"https://raw.githubusercontent.com/'
#
# b'stockpy/stockpy.github.io/master/%EC%A3%BC%EC%8B%9D%EC%B0%A8%ED%8A%B8.ipynb","type":"file","_links":{"self":"https://api.github.'
#
# b'com/repos/stockpy/stockpy.github.io/contents/%EC%A3%BC%EC%8B%9D%EC%B0%A8%ED%8A%B8.ipynb?ref=master","git":"https://api.github.co'
#
# b'm/repos/stockpy/stockpy.github.io/git/blobs/233190c485cdcaddd9665ddc2bc8ca7b5859beef","html":"https://github.com/stockpy/stockpy'
#
# b'.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%B0%A8%ED%8A%B8.ipynb"}},{"name":"\xec\xa3\xbc\xec\x8b\x9d\xec\xb2\xb4\xea\xb2\xb0.ipynb","path":"\xec\xa3\xbc\xec\x8b\x9d\xec\xb2\xb4\xea\xb2\xb0.ipynb","s'
#
# b'ha":"bd19dfe1a147d34bacead155b0adb3fb69a86e0f","size":6991,"url":"https://api.github.com/repos/stockpy/stockpy.github.io/content'
#
# b's/%EC%A3%BC%EC%8B%9D%EC%B2%B4%EA%B2%B0.ipynb?ref=master","html_url":"https://github.com/stockpy/stockpy.github.io/blob/master/%E'
#
# b'C%A3%BC%EC%8B%9D%EC%B2%B4%EA%B2%B0.ipynb","git_url":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/bd19dfe1a1'
#
# b'47d34bacead155b0adb3fb69a86e0f","download_url":"https://raw.githubusercontent.com/stockpy/stockpy.github.io/master/%EC%A3%BC%EC%'
#
# b'8B%9D%EC%B2%B4%EA%B2%B0.ipynb","type":"file","_links":{"self":"https://api.github.com/repos/stockpy/stockpy.github.io/contents/%'
#
# b'EC%A3%BC%EC%8B%9D%EC%B2%B4%EA%B2%B0.ipynb?ref=master","git":"https://api.github.com/repos/stockpy/stockpy.github.io/git/blobs/bd'
#
# b'19dfe1a147d34bacead155b0adb3fb69a86e0f","html":"https://github.com/stockpy/stockpy.github.io/blob/master/%EC%A3%BC%EC%8B%9D%EC%B'
#
# b'2%B4%EA%B2%B0.ipynb"}}]'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-682912b7c57b> in <module>
#      10 if(r.ok):
#      11     repoItem = json.loads(r.text or r.content)
# ---> 12     print("Django repository created: " + repoItem['created_at'])
#
# TypeError: list indices must be integers or slices, not str

# %%
# import github
# g = github.Github("stockpy", "Dlfdltka123!")
# repo = g.get_user().get_repo( "stockpy.github.io" )
# a = repo.get_dir_contents()

from github import Github

g = Github("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")
for repo in g.search_repositories("HDBPy"):
     for file in repo.get_contents("dir"):
          print(file.name)
# Out:
# ---------------------------------------------------------------------------
# UnknownObjectException                    Traceback (most recent call last)
# <ipython-input-23-a074970395ee> in <module>
#       8 g = Github("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")
#       9 for repo in g.search_repositories("HDBPy"):
# ---> 10      for file in repo.get_contents("dir"):
#      11           print(file.name)
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Repository.py in get_contents(self, path, ref)
#    1753             "GET",
#    1754             self.url + "/contents/" + urllib.parse.quote(path),
# -> 1755             parameters=url_parameters,
#    1756         )
#    1757
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# UnknownObjectException: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/reference/repos#get-repository-content"}

# %%
from github import Github
gh = Github(login_or_token='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', base_url='https://api.github.com/orgs/ORG/repos')
user = gh.get_user()
repo = user.get_repo("stockpy/HDBPy")
file = repo.get_file_contents("/App/forms.py")
# Out:
# ---------------------------------------------------------------------------
# UnknownObjectException                    Traceback (most recent call last)
# <ipython-input-26-04201afc88e8> in <module>
#       2 gh = Github(login_or_token='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', base_url='https://api.github.com/orgs/ORG/repos')
#       3 user = gh.get_user()
# ----> 4 repo = user.get_repo("stockpy/HDBPy")
#       5 file = repo.get_file_contents("/App/forms.py")
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\AuthenticatedUser.py in get_repo(self, name)
#    1016         assert isinstance(name, str), name
#    1017         headers, data = self._requester.requestJsonAndCheck(
# -> 1018             "GET", "/repos/" + self.login + "/" + name
#    1019         )
#    1020         return github.Repository.Repository(
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\AuthenticatedUser.py in login(self)
#     230         :type: string
#     231         """
# --> 232         self._completeIfNotSet(self._login)
#     233         return self._login.value
#     234
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\GithubObject.py in _completeIfNotSet(self, value)
#     297     def _completeIfNotSet(self, value):
#     298         if value is NotSet:
# --> 299             self._completeIfNeeded()
#     300
#     301     def _completeIfNeeded(self):
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\GithubObject.py in _completeIfNeeded(self)
#     301     def _completeIfNeeded(self):
#     302         if not self.__completed:
# --> 303             self.__complete()
#     304
#     305     def __complete(self):
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\GithubObject.py in __complete(self)
#     308                 400, "Returned object contains no URL"
#     309             )
# --> 310         headers, data = self._requester.requestJsonAndCheck("GET", self._url.value)
#     311         self._storeAndUseAttributes(headers, data)
#     312         self.__completed = True
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     317         return self.__check(
#     318             *self.requestJson(
# --> 319                 verb, url, parameters, headers, input, self.__customConnection(url)
#     320             )
#     321         )
#
# C:\Users\All Users\Anaconda3\lib\site-packages\github\Requester.py in __check(self, status, responseHeaders, output)
#     340         output = self.__structuredFromJson(output)
#     341         if status >= 400:
# --> 342             raise self.__createException(status, responseHeaders, output)
#     343         return responseHeaders, output
#     344
#
# UnknownObjectException: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest"}
